# %% [markdown]
# # [WITCOM 2024 - Puerto Vallarta, MX 🇲🇽🌊🤖](https://witcom.upiita.ipn.mx/)
#
# 👋🏽👋🏽 ¡Buen día! En esta pequeña demostración vamos a explorar el uso de modelos YANG para interactuar con nuestros dispositivos de red.
#
# ## Qué haremos en esta demostración
# - 🐍 Explorar la biblioteca de Python ncclient para interactuar vía NETCONF con un router Cisco
# - ⚙️ Explorar las capacidades del dispositivo
# - 🏗️ Explorar la estructura de un modelo de datos
# - ⚡️ Leer y modificar configuraciones del dispositivo
#
# Nuestro caso de uso van a ser las ```Listas de Control de Accesso```, o ```ACLs (Access Control Lists)```, que son configuraciones de seguridad que nos ayudar a filtar tipos muy específicos de tráfico en nuestros dispositivos de Capa 2 y Capa 3.
#
# Digamos que queremos configurar una ACL similar a la siguiente, pero usando NETCONF + otras herramientas de automatización:
#
# ***
# ```
# RP/0/RP0/CPU0:iosxr(config)# ipv4 access-list test-witcom-acl
# RP/0/RP0/CPU0:iosxr(config-ipv4-acl)# remark ACL de prueba WITCOM
# RP/0/RP0/CPU0:iosxr(config-ipv4-acl)# permit tcp 192.168.1.0 host 10.0.0.1 eq 80
# RP/0/RP0/CPU0:iosxr(config-ipv4-acl)# permit tcp any any eq 22
# RP/0/RP0/CPU0:iosxr(config-ipv4-acl)# deny udp any any eq 53
# RP/0/RP0/CPU0:iosxr(config-ipv4-acl)# deny ip any any
# RP/0/RP0/CPU0:iosxr(config-ipv4-acl)# commit
# ```
# ***
#
# Lo que hace esta ligeramente compleja ACL es lo siguiente:
#
# - Permite tráfico HTTP (puerto 80) desde 192.168.1.0 hacia 10.0.0.1.
# - Permite tráfico SSH (puerto 22)
# - Niega cualquier tráfico DNS (UDP/53)
# - Niega todo el resto del tráfico.

# %% [markdown]
# ### ⚙️ 1 - Explorando qué es lo que puede hacer mi router con sus modelos
# Para esta demostración vamos a ocupar un Router Cisco de la familia IOSXR que está disponible 24/7 en el [servicio de sandbox de DevNet](https://developer.cisco.com/docs/iosxr-python/sandbox/#ios-xr-sandboxes), además de la biblioteca de Python ```ncclient``` para el manejo de NETCONF.

# %%
from ncclient import manager
import re

IOSXR_HOST = 'sandbox-iosxr-1.cisco.com'      # FQDN de nuestro router
IOSXR_PORT = 830                              # Puerto NETCONF (por defecto es 830)
IOSXR_USERNAME = 'admin'                      # Usuario
IOSXR_PASSWORD = 'C1sco12345'                 # Password

# %% [markdown]
# Iniciemos ahora una sesión SSH con nuestro router.

# %%
xr = manager.connect(
    host=IOSXR_HOST,
    port=IOSXR_PORT,
    username=IOSXR_USERNAME,
    password=IOSXR_PASSWORD,
    hostkey_verify=False,
    allow_agent=False,
    look_for_keys=False
)

# %% [markdown]
# 🚀🚀 ¡Todo listo! Podemos hablar ahora con nuestro router usando NETCONF ...
#
# Lo primero que sucede cuando establecemos esta sesión es el envío de una lista con todos los nmodelos YANG que nuestro router puede manejar. Estos modelos hacen cosas diferentes, tal y como configuración de paramétros operacionales, servicios, valores operativos, etc.

# %%
for capability in xr.server_capabilities:
    print(capability)
# Out:
# urn:ietf:params:netconf:base:1.1
# urn:ietf:params:netconf:capability:candidate:1.0
# urn:ietf:params:netconf:capability:rollback-on-error:1.0
# urn:ietf:params:netconf:capability:validate:1.1
# urn:ietf:params:netconf:capability:confirmed-commit:1.1
# urn:ietf:params:netconf:capability:notification:1.0
# urn:ietf:params:netconf:capability:interleave:1.0
# http://cisco.com/ns/yang/Cisco-IOS-XR-um-event-manager-policy-map-cfg?module=Cisco-IOS-XR-um-event-manager-policy-map-cfg&revision=2021-06-16
# http://cisco.com/ns/yang/Cisco-IOS-XR-ip-mobileip-cfg?module=Cisco-IOS-XR-ip-mobileip-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-ma-oper?module=Cisco-IOS-XR-ipv4-ma-oper&revision=2019-10-25
# http://cisco.com/ns/yang/Cisco-IOS-XR-lpts-ifib-oper?module=Cisco-IOS-XR-lpts-ifib-oper&revision=2020-06-24
# http://cisco.com/ns/yang/Cisco-IOS-XR-um-router-ospfv3-cfg?module=Cisco-IOS-XR-um-router-ospfv3-cfg&revision=2021-02-12
# http://cisco.com/ns/yang/Cisco-IOS-XR-tunnel-ip-ea-oper?module=Cisco-IOS-XR-tunnel-ip-ea-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-qos-mibs-cfg?module=Cisco-IOS-XR-qos-mibs-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-mdrv-lib-cfg?module=Cisco-IOS-XR-mdrv-lib-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-mpls-te-datatypes?module=Cisco-IOS-XR-mpls-te-datatypes&revision=2019-09-30
# http://cisco.com/ns/yang/Cisco-IOS-XR-ip-static-cfg?module=Cisco-IOS-XR-ip-static-cfg&revision=2019-07-18
# http://cisco.com/ns/yang/Cisco-IOS-XR-ip-rip-cfg?module=Cisco-IOS-XR-ip-rip-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-drivers-media-eth-act?module=Cisco-IOS-XR-drivers-media-eth-act&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv6-new-dhcpv6d-client-cfg?module=Cisco-IOS-XR-ipv6-new-dhcpv6d-client-cfg&revision=2020-09-17
# http://cisco.com/ns/yang/Cisco-IOS-XR-aaa-lib-cfg?module=Cisco-IOS-XR-aaa-lib-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-ip-iep-cfg?module=Cisco-IOS-XR-ip-iep-cfg&revision=2019-10-31
# http://cisco.com/ns/yang/Cisco-IOS-XR-lpts-pre-ifib-oper?module=Cisco-IOS-XR-lpts-pre-ifib-oper&revision=2020-12-03
# http://cisco.com/ns/yang/Cisco-IOS-XR-authenticated-variable-act?module=Cisco-IOS-XR-authenticated-variable-act&revision=2020-07-10
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv6-ma-cfg?module=Cisco-IOS-XR-ipv6-ma-cfg&revision=2020-02-18
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-pim-cfg?module=Cisco-IOS-XR-ipv4-pim-cfg&revision=2019-10-31
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-acl-datatypes?module=Cisco-IOS-XR-ipv4-acl-datatypes&revision=2021-03-17
# http://cisco.com/ns/yang/Cisco-IOS-XR-lmp-datatypes?module=Cisco-IOS-XR-lmp-datatypes&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-crypto-cepki-cfg?module=Cisco-IOS-XR-crypto-cepki-cfg&revision=2021-05-13
# http://cisco.com/ns/yang/Cisco-IOS-XR-um-router-igmp-cfg?module=Cisco-IOS-XR-um-router-igmp-cfg&revision=2021-01-28
# http://cisco.com/ns/yang/Cisco-IOS-XR-manageability-object-tracking-cfg?module=Cisco-IOS-XR-manageability-object-tracking-cfg&revision=2020-03-26
# http://cisco.com/ns/yang/Cisco-IOS-XR-infra-syslog-cfg?module=Cisco-IOS-XR-infra-syslog-cfg&revision=2020-05-22
# http://cisco.com/ns/yang/Cisco-IOS-XR-infra-rsi-oper?module=Cisco-IOS-XR-infra-rsi-oper&revision=2020-09-21
# http://cisco.com/ns/yang/Cisco-IOS-XR-lldp-clear-act?module=Cisco-IOS-XR-lldp-clear-act&revision=2019-11-13
# http://cisco.com/ns/yang/Cisco-IOS-XR-infra-policymgr-cfg?module=Cisco-IOS-XR-infra-policymgr-cfg&revision=2021-02-15
# http://cisco.com/ns/yang/Cisco-IOS-XR-tunnel-nve-oper?module=Cisco-IOS-XR-tunnel-nve-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-subscriber-accounting-oper?module=Cisco-IOS-XR-subscriber-accounting-oper&revision=2019-12-16
# http://cisco.com/ns/yang/Cisco-IOS-XR-infra-notification-log-mib-cfg?module=Cisco-IOS-XR-infra-notification-log-mib-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-lib-type6-cfg?module=Cisco-IOS-XR-lib-type6-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-lib-type6-act?module=Cisco-IOS-XR-lib-type6-act&revision=2020-10-16
# http://cisco.com/ns/yang/Cisco-IOS-XR-ip-daps-mib-cfg?module=Cisco-IOS-XR-ip-daps-mib-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-ppp-ma-ssrp-cfg?module=Cisco-IOS-XR-ppp-ma-ssrp-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-lpts-lib-cfg?module=Cisco-IOS-XR-lpts-lib-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-ppp-ma-syslog-cfg?module=Cisco-IOS-XR-ppp-ma-syslog-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-infra-serg-cfg?module=Cisco-IOS-XR-infra-serg-cfg&revision=2020-11-22
# http://cisco.com/ns/yang/Cisco-IOS-XR-isis-act?module=Cisco-IOS-XR-isis-act&revision=2019-10-01
# http://cisco.com/ns/yang/Cisco-IOS-XR-infra-infra-locale-cfg?module=Cisco-IOS-XR-infra-infra-locale-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-snmp-ifmib-oper?module=Cisco-IOS-XR-snmp-ifmib-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-ospf-oper?module=Cisco-IOS-XR-ipv4-ospf-oper&revision=2021-06-01
# http://cisco.com/ns/yang/Cisco-IOS-XR-ppp-ma-gbl-cfg?module=Cisco-IOS-XR-ppp-ma-gbl-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-um-ipv4-access-list-cfg?module=Cisco-IOS-XR-um-ipv4-access-list-cfg&revision=2021-03-17&features=ipv4_acl_object_groups_supported,ipv4_acl_support_counter,ipv4_acl_protocol_range_implemented,ipv4_acl_abf_implemented,ipv4_acl_abf_track_implemented,ipv4_acl_rollback_permit_supported,IP_ACL_TCP_URG_FLAG_IMPLEMENTED,IP_ACL_TCP_FLEXFLAGS_IMPLEMENTED,ipv4_acl_pktlen_implemented,ipv4_acl_fragment_offset_implemented,ipv4_acl_is_frag_flags_supported,ipv4_acl_is_udf_supported,ipv4_acl_capture_implemented,ipv4_acl_is_set_action_supported,ipv4_acl_is_set_qos_group_supported,ipv4_acl_is_set_ttl_supported
# http://cisco.com/ns/yang/Cisco-IOS-XR-pbr-vrf-policy-cfg?module=Cisco-IOS-XR-pbr-vrf-policy-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-autorp-oper?module=Cisco-IOS-XR-ipv4-autorp-oper&revision=2019-08-27
# http://cisco.com/ns/yang/Cisco-IOS-XR-um-vrf-cfg?module=Cisco-IOS-XR-um-vrf-cfg&revision=2021-01-11
# http://cisco.com/ns/yang/Cisco-IOS-XR-linux-os-reboot-history-oper?module=Cisco-IOS-XR-linux-os-reboot-history-oper&revision=2021-07-28
# http://cisco.com/ns/yang/Cisco-IOS-XR-cli-cfg?module=Cisco-IOS-XR-cli-cfg&revision=2019-10-01
# http://cisco.com/ns/yang/Cisco-IOS-XR-ha-eem-cfg?module=Cisco-IOS-XR-ha-eem-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-ip-rsvp-cfg?module=Cisco-IOS-XR-ip-rsvp-cfg&revision=2019-09-20
# http://cisco.com/ns/yang/Cisco-IOS-XR-ip-raw-cfg?module=Cisco-IOS-XR-ip-raw-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-platform-inventory-oper?module=Cisco-IOS-XR-platform-inventory-oper&revision=2020-05-14
# http://cisco.com/ns/yang/Cisco-IOS-XR-aaa-tacacs-oper?module=Cisco-IOS-XR-aaa-tacacs-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-tunnel-l2tun-cfg?module=Cisco-IOS-XR-tunnel-l2tun-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-infra-xtc-agent-oper?module=Cisco-IOS-XR-infra-xtc-agent-oper&revision=2021-06-08
# http://cisco.com/ns/yang/Cisco-IOS-XR-mpls-oam-oper?module=Cisco-IOS-XR-mpls-oam-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-infra-rmf-oper?module=Cisco-IOS-XR-infra-rmf-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-mpls-traceroute-act?module=Cisco-IOS-XR-mpls-traceroute-act&revision=2021-07-12
# http://cisco.com/ns/yang/Cisco-IOS-XR-procmem-oper?module=Cisco-IOS-XR-procmem-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-sysdb-oper?module=Cisco-IOS-XR-sysdb-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-l2-eth-infra-cfg?module=Cisco-IOS-XR-l2-eth-infra-cfg&revision=2020-04-13
# http://cisco.com/ns/yang/Cisco-IOS-XR-ppp-ma-fsm-cfg?module=Cisco-IOS-XR-ppp-ma-fsm-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-flashmib-cfg?module=Cisco-IOS-XR-flashmib-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv6-acl-datatypes?module=Cisco-IOS-XR-ipv6-acl-datatypes&revision=2021-03-17
# http://cisco.com/ns/yang/Cisco-IOS-XR-infra-infra-cfg?module=Cisco-IOS-XR-infra-infra-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-ip-bfd-oper?module=Cisco-IOS-XR-ip-bfd-oper&revision=2020-05-20
# http://cisco.com/ns/yang/Cisco-IOS-XR-l2rib-oper?module=Cisco-IOS-XR-l2rib-oper&revision=2019-11-22
# http://cisco.com/ns/yang/cisco-semver?module=cisco-semver&revision=2019-03-13
# urn:ietf:params:xml:ns:yang:ietf-netconf-acm?module=ietf-netconf-acm&revision=2018-02-14&deviations=cisco-xr-ietf-netconf-acm-deviations
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-arp-cfg?module=Cisco-IOS-XR-ipv4-arp-cfg&revision=2019-05-12
# http://cisco.com/ns/yang/Cisco-IOS-XR-lmp-oper?module=Cisco-IOS-XR-lmp-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-infra-statsd-act?module=Cisco-IOS-XR-infra-statsd-act&revision=2019-10-01
# http://cisco.com/ns/yang/Cisco-IOS-XR-segment-routing-srv6-oper?module=Cisco-IOS-XR-segment-routing-srv6-oper&revision=2021-06-23
# http://cisco.com/ns/yang/Cisco-IOS-XR-ip-domain-oper?module=Cisco-IOS-XR-ip-domain-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-subscriber-accounting-cfg?module=Cisco-IOS-XR-subscriber-accounting-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-infra-script-mgmt-oper?module=Cisco-IOS-XR-infra-script-mgmt-oper&revision=2021-04-08
# http://cisco.com/ns/yang/Cisco-IOS-XR-infra-syslog-oper?module=Cisco-IOS-XR-infra-syslog-oper&revision=2020-09-22
# http://cisco.com/ns/yang/Cisco-IOS-XR-subscriber-session-mon-mibs-cfg?module=Cisco-IOS-XR-subscriber-session-mon-mibs-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-ppp-ma-cfg?module=Cisco-IOS-XR-ppp-ma-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-um-mpls-l3vpn-cfg?module=Cisco-IOS-XR-um-mpls-l3vpn-cfg&revision=2019-06-10
# http://cisco.com/ns/yang/Cisco-IOS-XR-mirror-oper?module=Cisco-IOS-XR-mirror-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv6-io-oper?module=Cisco-IOS-XR-ipv6-io-oper&revision=2019-10-21
# http://cisco.com/ns/yang/Cisco-IOS-XR-lpts-ifib-act?module=Cisco-IOS-XR-lpts-ifib-act&revision=2020-09-20
# http://cisco.com/ns/yang/Cisco-IOS-XR-controller-otu-cfg?module=Cisco-IOS-XR-controller-otu-cfg&revision=2020-07-23
# http://cisco.com/ns/yang/Cisco-IOS-XR-ip-sbfd-oper?module=Cisco-IOS-XR-ip-sbfd-oper&revision=2020-07-01
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv6-ospfv3-cfg?module=Cisco-IOS-XR-ipv6-ospfv3-cfg&revision=2020-04-28
# http://cisco.com/ns/yang/Cisco-IOS-XR-um-arp-cfg?module=Cisco-IOS-XR-um-arp-cfg&revision=2019-10-10
# http://cisco.com/ns/yang/Cisco-IOS-XR-Subscriber-infra-subdb-oper?module=Cisco-IOS-XR-Subscriber-infra-subdb-oper&revision=2020-04-02
# http://cisco.com/ns/yang/Cisco-IOS-XR-um-mpls-te-cfg?module=Cisco-IOS-XR-um-mpls-te-cfg&revision=2021-07-15
# http://cisco.com/ns/yang/Cisco-IOS-XR-cli-diff-act?module=Cisco-IOS-XR-cli-diff-act&revision=2019-10-01
# http://cisco.com/ns/yang/Cisco-IOS-XR-manageability-perfmgmt-cfg?module=Cisco-IOS-XR-manageability-perfmgmt-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-aaa-diameter-base-mib-cfg?module=Cisco-IOS-XR-aaa-diameter-base-mib-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-aaa-nacm-cfg?module=Cisco-IOS-XR-aaa-nacm-cfg&revision=2020-06-01
# http://cisco.com/ns/yang/Cisco-IOS-XR-pmengine-clear-act?module=Cisco-IOS-XR-pmengine-clear-act&revision=2020-09-13
# http://cisco.com/ns/yang/Cisco-IOS-XR-igmp-oper?module=Cisco-IOS-XR-igmp-oper&revision=2021-02-03
# http://cisco.com/ns/yang/Cisco-IOS-XR-upgrade-fpd-ng-act?module=Cisco-IOS-XR-upgrade-fpd-ng-act&revision=2019-10-01
# http://cisco.com/ns/yang/Cisco-IOS-XR-invmgr-cfg?module=Cisco-IOS-XR-invmgr-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-telnet-cfg?module=Cisco-IOS-XR-ipv4-telnet-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-remote-attestation-act?module=Cisco-IOS-XR-remote-attestation-act&revision=2020-07-10
# http://cisco.com/ns/yang/Cisco-IOS-XR-infra-tc-cfg?module=Cisco-IOS-XR-infra-tc-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-dhcpd-subscriber-cfg?module=Cisco-IOS-XR-ipv4-dhcpd-subscriber-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-infra-objmgr-oper?module=Cisco-IOS-XR-infra-objmgr-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-mediasvr-linux-oper?module=Cisco-IOS-XR-mediasvr-linux-oper&revision=2020-07-11
# http://cisco.com/ns/yang/Cisco-IOS-XR-man-netconf-oper?module=Cisco-IOS-XR-man-netconf-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-igp-topodb-oper?module=Cisco-IOS-XR-igp-topodb-oper&revision=2021-06-01
# http://cisco.com/ns/yang/Cisco-IOS-XR-mpls-vpn-oper?module=Cisco-IOS-XR-mpls-vpn-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-attestation-agent-ima-oper?module=Cisco-IOS-XR-attestation-agent-ima-oper&revision=2020-09-21
# http://cisco.com/ns/yang/Cisco-IOS-XR-ip-tcp-cfg?module=Cisco-IOS-XR-ip-tcp-cfg&revision=2020-05-16
# http://cisco.com/ns/yang/Cisco-IOS-XR-um-object-group-cfg?module=Cisco-IOS-XR-um-object-group-cfg&revision=2020-10-07
# http://cisco.com/ns/yang/Cisco-IOS-XR-ifmgr-cfg?module=Cisco-IOS-XR-ifmgr-cfg&revision=2020-10-01
# http://cisco.com/ns/yang/Cisco-IOS-XR-segment-routing-srv6-cfg?module=Cisco-IOS-XR-segment-routing-srv6-cfg&revision=2019-11-21
# http://cisco.com/ns/yang/Cisco-IOS-XR-sysmgr-cfg?module=Cisco-IOS-XR-sysmgr-cfg&revision=2019-10-31
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-io-oper?module=Cisco-IOS-XR-ipv4-io-oper&revision=2019-10-01
# http://cisco.com/ns/yang/Cisco-IOS-XR-mpls-ldp-cfg-datatypes?module=Cisco-IOS-XR-mpls-ldp-cfg-datatypes&revision=2019-04-05
# urn:ietf:params:xml:ns:yang:ietf-syslog-types?module=ietf-syslog-types&revision=2015-11-09
# http://cisco.com/ns/yang/Cisco-IOS-XR-um-router-amt-cfg?module=Cisco-IOS-XR-um-router-amt-cfg&revision=2019-08-20
# http://cisco.com/ns/yang/Cisco-IOS-XR-ip-daps-oper?module=Cisco-IOS-XR-ip-daps-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-man-xml-ttyagent-oper?module=Cisco-IOS-XR-man-xml-ttyagent-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-pmengine-gl-cfg?module=Cisco-IOS-XR-pmengine-gl-cfg&revision=2020-08-20
# http://cisco.com/ns/yang/Cisco-IOS-XR-um-event-manager-cfg?module=Cisco-IOS-XR-um-event-manager-cfg&revision=2021-08-04
# http://cisco.com/ns/yang/Cisco-IOS-XR-manageability-perfmgmt-oper?module=Cisco-IOS-XR-manageability-perfmgmt-oper&revision=2020-11-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-aaa-diameter-oper?module=Cisco-IOS-XR-aaa-diameter-oper&revision=2020-10-19
# http://cisco.com/ns/yang/Cisco-IOS-XR-ssm-cfg?module=Cisco-IOS-XR-ssm-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-segment-routing-ms-cfg?module=Cisco-IOS-XR-segment-routing-ms-cfg&revision=2019-06-19
# http://cisco.com/ns/yang/Cisco-IOS-XR-um-policymap-classmap-cfg?module=Cisco-IOS-XR-um-policymap-classmap-cfg&revision=2020-10-05&features=pmap-type-qos,pmap-type-pbr,pmap-type-accounting,pmap-type-redirect,pmap-type-traffic,pmap-type-control,pmap-type-afmon,cmap-type-qos,cmap-type-traffic,match-ipv4-acl,match-ipv6-acl,match-ethernet-services-acl,match-ipv4-dscp,match-ipv4-prec,match-ipv6-dscp,match-ipv6-prec,match-dscp,match-prec,match-proto,match-mpls-exp-top,match-cos,match-cos-inner,match-vlan,match-vlan-inner,match-source-port,match-destination-port,match-src-mac,match-dst-mac,match-src-addr-ipv4,match-dst-addr-ipv4,match-src-addr-ipv6,match-dst-addr-ipv6,match-atm,match-cac,match-dei,match-dei-inner,match-discard-class,match-ethertype,match-flow-key,match-fragment-type,match-fr-de,match-fr,match-mpls-disp-ipv4-acl,match-mpls-disp-ipv6-acl,match-mpls-disp-cmap,match-mpls-exp-imposition,match-ipv4-packet-length,match-ipv6-packet-length,match-authen-status,match-timer,match-username,match-vpls-known,match-vpls-unknown,match-vpls-control,matchnot-ipv4-acl,matchnot-ipv6-acl,matchnot-es-acl,matchnot-cac-local,matchnot-dei,matchnot-authen-status,matchnot-protocol,matchnot-timer,matchnot-username,matchnot-ethertype,matchnot-fr-de,matchnot-fr,matchnot-ipv4-packet-length,matchnot-ipv6-packet-length,matchnot-vlan,matchnot-vlan-inner,matchnot-vpls-known,matchnot-vpls-unknown,matchnot-vpls-bcast,matchnot-vpls-control,matchnot-vpls-mcast,matchnot-flow-tag,matchnot-mac-address,matchnot-mpls-disp-ipv4-acl,matchnot-mpls-disp-ipv6-acl,action-compress-header-ip,action-encap-sequence,action-authenticate,action-authorize,action-disconnect,action-monitor,action-set-timer,action-stop-timer,action-http-redirect,action-http-enrichment,action-redirect-nexthop,action-redirect-rt,action-service-function,action-set-dst-address,action-set-df,action-set-fwd-class,action-set-src-address,action-transmit,action-decap-gre,action-react,action-react-snmp,action-react-alarm,action-react-grouped-alarm,action-cac,action-bandwidth,action-service-fragment,action-pfc,action-police-peak-burst,action-police-conform-color,action-police-exceed-color,action-police-coupled,action-police-set-fr-de,action-set-atm-clp,action-set-traffic-class,action-shape-burst
# http://cisco.com/ns/yang/Cisco-IOS-XR-man-netconf-cfg?module=Cisco-IOS-XR-man-netconf-cfg&revision=2019-12-12
# http://cisco.com/ns/yang/Cisco-IOS-XR-l2rib-cfg?module=Cisco-IOS-XR-l2rib-cfg&revision=2019-09-09
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv6-ospfv3-oper?module=Cisco-IOS-XR-ipv6-ospfv3-oper&revision=2020-04-29
# http://cisco.com/ns/yang/Cisco-IOS-XR-infra-policymgr-oper?module=Cisco-IOS-XR-infra-policymgr-oper&revision=2020-05-19
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv6-new-dhcpv6d-cfg?module=Cisco-IOS-XR-ipv6-new-dhcpv6d-cfg&revision=2021-05-28
# http://cisco.com/ns/yang/Cisco-IOS-XR-crypto-act?module=Cisco-IOS-XR-crypto-act&revision=2020-09-18
# http://cisco.com/ns/yang/Cisco-IOS-XR-qos-ma-cfg?module=Cisco-IOS-XR-qos-ma-cfg&revision=2020-03-10
# http://cisco.com/ns/yang/Cisco-IOS-XR-ethernet-lldp-oper?module=Cisco-IOS-XR-ethernet-lldp-oper&revision=2020-09-01
# http://cisco.com/ns/yang/Cisco-IOS-XR-um-grpc-cfg?module=Cisco-IOS-XR-um-grpc-cfg&revision=2021-05-20
# http://cisco.com/ns/yang/Cisco-IOS-XR-man-ems-oper?module=Cisco-IOS-XR-man-ems-oper&revision=2020-03-19
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-bgp-cfg?module=Cisco-IOS-XR-ipv4-bgp-cfg&revision=2021-06-30
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv6-nd-oper?module=Cisco-IOS-XR-ipv6-nd-oper&revision=2019-11-08
# http://cisco.com/ns/yang/Cisco-IOS-XR-ip-bfd-cfg?module=Cisco-IOS-XR-ip-bfd-cfg&revision=2019-10-31
# http://cisco.com/ns/yang/Cisco-IOS-XR-um-interface-cfg?module=Cisco-IOS-XR-um-interface-cfg&revision=2019-06-10
# http://cisco.com/ns/yang/Cisco-IOS-XR-cdp-cfg?module=Cisco-IOS-XR-cdp-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-fpmgr-oper?module=Cisco-IOS-XR-fpmgr-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-um-lacp-cfg?module=Cisco-IOS-XR-um-lacp-cfg&revision=2019-06-10
# http://cisco.com/ns/yang/Cisco-IOS-XR-infra-alarm-logger-cfg?module=Cisco-IOS-XR-infra-alarm-logger-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-ip-udp-cfg?module=Cisco-IOS-XR-ip-udp-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv6-io-cfg?module=Cisco-IOS-XR-ipv6-io-cfg&revision=2019-10-31
# http://cisco.com/ns/yang/Cisco-IOS-XR-clns-isis-oper?module=Cisco-IOS-XR-clns-isis-oper&revision=2021-03-13
# http://cisco.com/ns/yang/Cisco-IOS-XR-um-if-bundle-cfg?module=Cisco-IOS-XR-um-if-bundle-cfg&revision=2020-12-21
# http://cisco.com/ns/yang/Cisco-IOS-XR-attestation-agent-cfg?module=Cisco-IOS-XR-attestation-agent-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-um-router-pim-cfg?module=Cisco-IOS-XR-um-router-pim-cfg&revision=2021-01-28
# http://cisco.com/ns/yang/Cisco-IOS-XR-ppp-ma-ipcpiw-cfg?module=Cisco-IOS-XR-ppp-ma-ipcpiw-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-bgp-oper?module=Cisco-IOS-XR-ipv4-bgp-oper&revision=2021-05-10
# http://cisco.com/ns/yang/Cisco-IOS-XR-syslog-act?module=Cisco-IOS-XR-syslog-act&revision=2019-10-01
# http://cisco.com/ns/yang/Cisco-IOS-XR-bundlemgr-oper?module=Cisco-IOS-XR-bundlemgr-oper&revision=2020-10-01
# http://cisco.com/ns/yang/Cisco-IOS-XR-subscriber-pppoe-ma-oper?module=Cisco-IOS-XR-subscriber-pppoe-ma-oper&revision=2019-10-07
# http://cisco.com/ns/yang/Cisco-IOS-XR-alarmgr-server-oper?module=Cisco-IOS-XR-alarmgr-server-oper&revision=2021-05-06
# http://cisco.com/ns/yang/Cisco-IOS-XR-man-ems-cfg?module=Cisco-IOS-XR-man-ems-cfg&revision=2019-06-02
# http://cisco.com/ns/yang/Cisco-IOS-XR-mpls-te-oper?module=Cisco-IOS-XR-mpls-te-oper&revision=2020-11-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-aaa-nacm-oper?module=Cisco-IOS-XR-aaa-nacm-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-mpls-oam-cfg?module=Cisco-IOS-XR-mpls-oam-cfg&revision=2019-05-12
# http://cisco.com/ns/yang/Cisco-IOS-XR-ppp-ma-oper?module=Cisco-IOS-XR-ppp-ma-oper&revision=2021-06-15
# http://cisco.com/ns/yang/Cisco-IOS-XR-sdr-invmgr-diag-oper?module=Cisco-IOS-XR-sdr-invmgr-diag-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-bgp-datatypes?module=Cisco-IOS-XR-ipv4-bgp-datatypes&revision=2019-08-31
# http://cisco.com/ns/yang/Cisco-IOS-XR-um-l2-ethernet-cfg?module=Cisco-IOS-XR-um-l2-ethernet-cfg&revision=2020-08-01&features=global-ethernet
# http://cisco.com/ns/yang/Cisco-IOS-XR-snmp-ciscopkimib-traps-cfg?module=Cisco-IOS-XR-snmp-ciscopkimib-traps-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-infra-ltrace-cfg?module=Cisco-IOS-XR-infra-ltrace-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-tty-management-datatypes?module=Cisco-IOS-XR-tty-management-datatypes&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-lib-keychain-cfg?module=Cisco-IOS-XR-lib-keychain-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-lib-keychain-act?module=Cisco-IOS-XR-lib-keychain-act&revision=2019-10-01
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-hsrp-cfg?module=Cisco-IOS-XR-ipv4-hsrp-cfg&revision=2019-10-31
# http://cisco.com/ns/yang/Cisco-IOS-XR-ppp-ea-oper?module=Cisco-IOS-XR-ppp-ea-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-cdp-oper?module=Cisco-IOS-XR-cdp-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-xrv9k-lpts-oper?module=Cisco-IOS-XR-xrv9k-lpts-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-sysmgr-oper?module=Cisco-IOS-XR-sysmgr-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-um-if-access-group-cfg?module=Cisco-IOS-XR-um-if-access-group-cfg&revision=2019-06-10
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-smiap-cfg?module=Cisco-IOS-XR-ipv4-smiap-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-mvpn-oper?module=Cisco-IOS-XR-mvpn-oper&revision=2020-04-02
# http://cisco.com/ns/yang/Cisco-IOS-XR-subscriber-srg-oper?module=Cisco-IOS-XR-subscriber-srg-oper&revision=2019-10-03
# http://cisco.com/ns/yang/Cisco-IOS-XR-infra-statsd-cfg?module=Cisco-IOS-XR-infra-statsd-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-tty-server-cfg?module=Cisco-IOS-XR-tty-server-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-flowspec-cfg?module=Cisco-IOS-XR-flowspec-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-nto-misc-oper?module=Cisco-IOS-XR-nto-misc-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-crypto-mibs-ipsecflowmon-cfg?module=Cisco-IOS-XR-crypto-mibs-ipsecflowmon-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-parser-cfg?module=Cisco-IOS-XR-parser-cfg&revision=2019-11-08
# http://cisco.com/ns/yang/Cisco-IOS-XR-um-if-service-policy-qos-cfg?module=Cisco-IOS-XR-um-if-service-policy-qos-cfg&revision=2020-10-01&features=service-policy,account-user-def,shared-policy-instance,sub-parent-policy,sub-group,sfrag-parent-policy,ipsec-policy,egress,ingress,qfab
# http://cisco.com/ns/yang/Cisco-IOS-XR-manageability-object-tracking-datatypes?module=Cisco-IOS-XR-manageability-object-tracking-datatypes&revision=2019-11-22
# http://cisco.com/ns/yang/Cisco-IOS-XR-um-mpls-lsd-cfg?module=Cisco-IOS-XR-um-mpls-lsd-cfg&revision=2021-01-28
# http://cisco.com/ns/yang/Cisco-IOS-XR-ip-ntp-oper?module=Cisco-IOS-XR-ip-ntp-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-arp-oper?module=Cisco-IOS-XR-ipv4-arp-oper&revision=2020-12-03
# http://cisco.com/ns/yang/Cisco-IOS-XR-um-router-msdp-cfg?module=Cisco-IOS-XR-um-router-msdp-cfg&revision=2021-01-08
# http://cisco.com/ns/yang/Cisco-IOS-XR-um-ethernet-services-access-list-cfg?module=Cisco-IOS-XR-um-ethernet-services-access-list-cfg&revision=2020-12-03&features=es_acl_supported,es_acl_capture_implemented,es_acl_log_option_supported
# http://cisco.com/ns/yang/Cisco-IOS-XR-install-act?module=Cisco-IOS-XR-install-act&revision=2019-12-10
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-acl-oper?module=Cisco-IOS-XR-ipv4-acl-oper&revision=2020-11-13
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv6-ma-subscriber-cfg?module=Cisco-IOS-XR-ipv6-ma-subscriber-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-um-ipv6-prefix-list-cfg?module=Cisco-IOS-XR-um-ipv6-prefix-list-cfg&revision=2020-12-03
# http://cisco.com/ns/yang/Cisco-IOS-XR-um-router-bgp-cfg?module=Cisco-IOS-XR-um-router-bgp-cfg&revision=2021-02-25
# http://cisco.com/ns/yang/Cisco-IOS-XR-lpts-pre-ifib-cfg?module=Cisco-IOS-XR-lpts-pre-ifib-cfg&revision=2020-08-26
# http://cisco.com/ns/yang/Cisco-IOS-XR-spirit-install-act?module=Cisco-IOS-XR-spirit-install-act&revision=2019-12-03
# http://cisco.com/ns/yang/Cisco-IOS-XR-kim-tpa-cfg?module=Cisco-IOS-XR-kim-tpa-cfg&revision=2019-12-17
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-arp-act?module=Cisco-IOS-XR-ipv4-arp-act&revision=2020-10-01
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-autorp-datatypes?module=Cisco-IOS-XR-ipv4-autorp-datatypes&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-filesystems-cfg?module=Cisco-IOS-XR-ipv4-filesystems-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-hwmod-mpa-reload-act?module=Cisco-IOS-XR-hwmod-mpa-reload-act&revision=2019-10-01
# http://cisco.com/ns/yang/Cisco-IOS-XR-snmp-ciscosensormib-cfg?module=Cisco-IOS-XR-snmp-ciscosensormib-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-tty-server-oper?module=Cisco-IOS-XR-tty-server-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-um-if-mpls-cfg?module=Cisco-IOS-XR-um-if-mpls-cfg&revision=2019-06-10
# http://cisco.com/ns/yang/Cisco-IOS-XR-mpls-io-cfg?module=Cisco-IOS-XR-mpls-io-cfg&revision=2019-05-12
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-dhcpd-oper?module=Cisco-IOS-XR-ipv4-dhcpd-oper&revision=2021-06-21
# http://cisco.com/ns/yang/Cisco-IOS-XR-tty-management-cfg?module=Cisco-IOS-XR-tty-management-cfg&revision=2020-10-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-snmp-bridgemib-cfg?module=Cisco-IOS-XR-snmp-bridgemib-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-infra-alarm-logger-datatypes?module=Cisco-IOS-XR-infra-alarm-logger-datatypes&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-eigrp-oper?module=Cisco-IOS-XR-eigrp-oper&revision=2020-09-14
# http://cisco.com/ns/yang/Cisco-IOS-XR-drivers-media-eth-gl-pfc-wd-cfg?module=Cisco-IOS-XR-drivers-media-eth-gl-pfc-wd-cfg&revision=2019-08-15
# http://cisco.com/ns/yang/Cisco-IOS-XR-pppoe-ea-oper?module=Cisco-IOS-XR-pppoe-ea-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-ip-iarm-vrf-cfg?module=Cisco-IOS-XR-ip-iarm-vrf-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-mfwd-oper?module=Cisco-IOS-XR-mfwd-oper&revision=2020-10-11
# http://cisco.com/ns/yang/Cisco-IOS-XR-shellutil-copy-act?module=Cisco-IOS-XR-shellutil-copy-act&revision=2019-10-01
# http://cisco.com/ns/yang/Cisco-IOS-XR-ip-static-ipv6-oper?module=Cisco-IOS-XR-ip-static-ipv6-oper&revision=2019-12-12
# http://cisco.com/ns/yang/Cisco-IOS-XR-ip-iarm-v6-oper?module=Cisco-IOS-XR-ip-iarm-v6-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-lib-type6-server-oper?module=Cisco-IOS-XR-lib-type6-server-oper&revision=2019-09-20
# http://cisco.com/ns/yang/Cisco-IOS-XR-aaa-aaacore-cfg?module=Cisco-IOS-XR-aaa-aaacore-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-l2-eth-infra-oper?module=Cisco-IOS-XR-l2-eth-infra-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-infra-tc-oper?module=Cisco-IOS-XR-infra-tc-oper&revision=2019-06-17
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-ma-subscriber-cfg?module=Cisco-IOS-XR-ipv4-ma-subscriber-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-mpls-vpn-cfg?module=Cisco-IOS-XR-mpls-vpn-cfg&revision=2019-05-12
# http://cisco.com/ns/yang/Cisco-IOS-XR-subscriber-infra-tmplmgr-cfg?module=Cisco-IOS-XR-subscriber-infra-tmplmgr-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-pbr-vservice-ea-oper?module=Cisco-IOS-XR-pbr-vservice-ea-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-cfgmgr-cfs-check-act?module=Cisco-IOS-XR-cfgmgr-cfs-check-act&revision=2020-09-10
# http://cisco.com/ns/yang/Cisco-IOS-XR-opendns-deviceid-cfg?module=Cisco-IOS-XR-opendns-deviceid-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-adt-config-cfg?module=Cisco-IOS-XR-adt-config-cfg&revision=2020-10-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-fpmgr-cfg?module=Cisco-IOS-XR-fpmgr-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-config-mda-cfg?module=Cisco-IOS-XR-config-mda-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-tunnel-gre-cfg?module=Cisco-IOS-XR-tunnel-gre-cfg&revision=2020-02-02
# http://cisco.com/ns/yang/Cisco-IOS-XR-manageability-perfmgmt-datatypes?module=Cisco-IOS-XR-manageability-perfmgmt-datatypes&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-rsi-agent-oper?module=Cisco-IOS-XR-rsi-agent-oper&revision=2020-12-18
# http://cisco.com/ns/yang/Cisco-IOS-XR-snmp-entitymib-cfg?module=Cisco-IOS-XR-snmp-entitymib-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-infra-correlator-cfg?module=Cisco-IOS-XR-infra-correlator-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-ip-rib-cfg?module=Cisco-IOS-XR-ip-rib-cfg&revision=2019-05-12
# http://cisco.com/ns/yang/Cisco-IOS-XR-pbr-bng-cfg?module=Cisco-IOS-XR-pbr-bng-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-appmgr-cfg?module=Cisco-IOS-XR-appmgr-cfg&revision=2021-04-04
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv6-nd-subscriber-cfg?module=Cisco-IOS-XR-ipv6-nd-subscriber-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-pim-oper?module=Cisco-IOS-XR-ipv4-pim-oper&revision=2020-10-11
# http://cisco.com/ns/yang/Cisco-IOS-XR-config-cfgmgr-cfg?module=Cisco-IOS-XR-config-cfgmgr-cfg&revision=2020-06-26
# http://cisco.com/ns/yang/Cisco-IOS-XR-pmengine-oper?module=Cisco-IOS-XR-pmengine-oper&revision=2020-09-02
# http://cisco.com/ns/yang/Cisco-IOS-XR-aaa-locald-cfg?module=Cisco-IOS-XR-aaa-locald-cfg&revision=2019-11-24
# http://cisco.com/ns/yang/Cisco-IOS-XR-crypto-ssh-oper?module=Cisco-IOS-XR-crypto-ssh-oper&revision=2021-09-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-mpls-io-oper?module=Cisco-IOS-XR-mpls-io-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-um-traps-mpls-ldp-cfg?module=Cisco-IOS-XR-um-traps-mpls-ldp-cfg&revision=2019-10-10
# http://cisco.com/ns/yang/Cisco-IOS-XR-lmp-cfg?module=Cisco-IOS-XR-lmp-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-shellutil-oper?module=Cisco-IOS-XR-shellutil-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-snmp-test-trap-act?module=Cisco-IOS-XR-snmp-test-trap-act&revision=2019-10-01
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-bgp-oc-oper?module=Cisco-IOS-XR-ipv4-bgp-oc-oper&revision=2020-01-28
# http://cisco.com/ns/yang/Cisco-IOS-XR-infra-xtc-oper?module=Cisco-IOS-XR-infra-xtc-oper&revision=2021-06-21
# http://cisco.com/ns/yang/Cisco-IOS-XR-pfi-im-cmd-ctrlr-oper?module=Cisco-IOS-XR-pfi-im-cmd-ctrlr-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-tunnel-vpdn-cfg?module=Cisco-IOS-XR-tunnel-vpdn-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-um-rsvp-cfg?module=Cisco-IOS-XR-um-rsvp-cfg&revision=2021-01-28
# http://cisco.com/ns/yang/Cisco-IOS-XR-appmgr-act?module=Cisco-IOS-XR-appmgr-act&revision=2021-03-01
# http://cisco.com/ns/yang/Cisco-IOS-XR-shellutil-filesystem-oper?module=Cisco-IOS-XR-shellutil-filesystem-oper&revision=2021-03-22
# http://cisco.com/ns/yang/Cisco-IOS-XR-um-multicast-routing-cfg?module=Cisco-IOS-XR-um-multicast-routing-cfg&revision=2021-07-22
# http://cisco.com/ns/yang/Cisco-IOS-XR-call-home-cfg?module=Cisco-IOS-XR-call-home-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-mpls-ldp-oper?module=Cisco-IOS-XR-mpls-ldp-oper&revision=2021-04-06
# http://cisco.com/ns/yang/Cisco-IOS-XR-clear-counters-act?module=Cisco-IOS-XR-clear-counters-act&revision=2019-10-01
# http://cisco.com/ns/yang/Cisco-IOS-XR-aaa-li-cfg?module=Cisco-IOS-XR-aaa-li-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-tty-management-cmd-oper?module=Cisco-IOS-XR-tty-management-cmd-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-pmengine-cfg?module=Cisco-IOS-XR-pmengine-cfg&revision=2020-04-17
# http://cisco.com/ns/yang/Cisco-IOS-XR-controller-ains-act?module=Cisco-IOS-XR-controller-ains-act&revision=2019-10-01
# http://cisco.com/ns/yang/Cisco-IOS-XR-subscriber-ipsub-cfg?module=Cisco-IOS-XR-subscriber-ipsub-cfg&revision=2019-10-31
# http://cisco.com/ns/yang/Cisco-IOS-XR-controller-odu-oper?module=Cisco-IOS-XR-controller-odu-oper&revision=2020-11-11
# http://cisco.com/ns/yang/Cisco-IOS-XR-install-oper?module=Cisco-IOS-XR-install-oper&revision=2020-07-23
# http://cisco.com/ns/yang/Cisco-IOS-XR-manageability-object-tracking-oper?module=Cisco-IOS-XR-manageability-object-tracking-oper&revision=2020-06-17
# http://cisco.com/ns/yang/Cisco-IOS-XR-um-conflict-policy-cfg?module=Cisco-IOS-XR-um-conflict-policy-cfg&revision=2021-05-04
# http://cisco.com/ns/yang/Cisco-IOS-XR-um-if-ethernet-cfg?module=Cisco-IOS-XR-um-if-ethernet-cfg&revision=2019-12-12
# http://cisco.com/ns/yang/Cisco-IOS-XR-accounting-cfg?module=Cisco-IOS-XR-accounting-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv6-acl-cfg?module=Cisco-IOS-XR-ipv6-acl-cfg&revision=2021-03-17
# http://cisco.com/ns/yang/Cisco-IOS-XR-dwdm-ui-cfg?module=Cisco-IOS-XR-dwdm-ui-cfg&revision=2020-02-04
# http://cisco.com/ns/yang/Cisco-IOS-XR-segment-routing-ms-common-cfg?module=Cisco-IOS-XR-segment-routing-ms-common-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-um-ipv4-prefix-list-cfg?module=Cisco-IOS-XR-um-ipv4-prefix-list-cfg&revision=2020-12-03
# http://cisco.com/ns/yang/Cisco-IOS-XR-um-router-static-cfg?module=Cisco-IOS-XR-um-router-static-cfg&revision=2019-06-10
# http://cisco.com/ns/yang/Cisco-IOS-XR-ip-rib-ipv4-oper?module=Cisco-IOS-XR-ip-rib-ipv4-oper&revision=2020-12-11
# http://cisco.com/ns/yang/Cisco-IOS-XR-ip-static-ipv4-oper?module=Cisco-IOS-XR-ip-static-ipv4-oper&revision=2019-12-12
# http://cisco.com/ns/yang/Cisco-IOS-XR-crypto-sam-oper?module=Cisco-IOS-XR-crypto-sam-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-igmp-dyn-tmpl-cfg?module=Cisco-IOS-XR-ipv4-igmp-dyn-tmpl-cfg&revision=2021-03-22
# http://cisco.com/ns/yang/Cisco-IOS-XR-snmp-agent-cfg?module=Cisco-IOS-XR-snmp-agent-cfg&revision=2020-03-31
# http://cisco.com/ns/yang/Cisco-IOS-XR-opticalmib-cfg?module=Cisco-IOS-XR-opticalmib-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-snmp-entityextmib-cfg?module=Cisco-IOS-XR-snmp-entityextmib-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-cinetd-cfg?module=Cisco-IOS-XR-ipv4-cinetd-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-es-acl-datatypes?module=Cisco-IOS-XR-es-acl-datatypes&revision=2019-04-05
# urn:ietf:params:xml:ns:netconf:notification:1.0?module=notifications&revision=2008-07-14
# http://cisco.com/ns/yang/Cisco-IOS-XR-perf-meas-cfg?module=Cisco-IOS-XR-perf-meas-cfg&revision=2021-02-12
# http://cisco.com/ns/yang/Cisco-IOS-XR-mpls-ldp-oper-datatypes?module=Cisco-IOS-XR-mpls-ldp-oper-datatypes&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-mpls-static-cfg?module=Cisco-IOS-XR-mpls-static-cfg&revision=2021-06-16
# http://cisco.com/ns/yang/Cisco-IOS-XR-tunnel-ip-ma-oper?module=Cisco-IOS-XR-tunnel-ip-ma-oper&revision=2021-02-25
# http://cisco.com/ns/yang/Cisco-IOS-XR-config-cfgmgr-exec-augmented-oper?module=Cisco-IOS-XR-config-cfgmgr-exec-augmented-oper&revision=2020-06-02
# http://cisco.com/ns/yang/Cisco-IOS-XR-snmp-syslogmib-cfg?module=Cisco-IOS-XR-snmp-syslogmib-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-infra-xtc-cfg?module=Cisco-IOS-XR-infra-xtc-cfg&revision=2021-07-12
# http://cisco.com/ns/yang/Cisco-IOS-XR-filesysinv-cfg?module=Cisco-IOS-XR-filesysinv-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-common-acl-datatypes?module=Cisco-IOS-XR-common-acl-datatypes&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-wdsysmon-fd-proc-oper?module=Cisco-IOS-XR-wdsysmon-fd-proc-oper&revision=2020-04-19
# http://cisco.com/ns/yang/Cisco-IOS-XR-um-if-ipv4-cfg?module=Cisco-IOS-XR-um-if-ipv4-cfg&revision=2020-10-02
# http://cisco.com/ns/yang/Cisco-IOS-XR-infra-script-mgmt-act?module=Cisco-IOS-XR-infra-script-mgmt-act&revision=2020-10-12
# http://cisco.com/ns/yang/Cisco-IOS-XR-infra-statsd-oper?module=Cisco-IOS-XR-infra-statsd-oper&revision=2020-12-17
# http://cisco.com/ns/yang/Cisco-IOS-XR-es-acl-cfg?module=Cisco-IOS-XR-es-acl-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-ip-mobileip-oper?module=Cisco-IOS-XR-ip-mobileip-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-fib-common-oper?module=Cisco-IOS-XR-fib-common-oper&revision=2021-03-10
# http://cisco.com/ns/yang/Cisco-IOS-XR-um-router-isis-cfg?module=Cisco-IOS-XR-um-router-isis-cfg&revision=2021-01-20
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-ospf-cfg?module=Cisco-IOS-XR-ipv4-ospf-cfg&revision=2020-10-12
# http://cisco.com/ns/yang/Cisco-IOS-XR-mpls-te-cfg?module=Cisco-IOS-XR-mpls-te-cfg&revision=2021-06-10
# http://cisco.com/ns/yang/Cisco-IOS-XR-crypto-ssh-cfg?module=Cisco-IOS-XR-crypto-ssh-cfg&revision=2021-09-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-pbr-datatypes?module=Cisco-IOS-XR-pbr-datatypes&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv6-new-dhcpv6d-subscriber-cfg?module=Cisco-IOS-XR-ipv6-new-dhcpv6d-subscriber-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-mpls-ldp-mldp-oper?module=Cisco-IOS-XR-mpls-ldp-mldp-oper&revision=2020-10-18
# http://cisco.com/ns/yang/Cisco-IOS-XR-lib-mpp-cfg?module=Cisco-IOS-XR-lib-mpp-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-ip-pfilter-cfg?module=Cisco-IOS-XR-ip-pfilter-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-aaa-protocol-radius-cfg?module=Cisco-IOS-XR-aaa-protocol-radius-cfg&revision=2020-08-26
# http://cisco.com/ns/yang/Cisco-IOS-XR-mpls-lsd-oper?module=Cisco-IOS-XR-mpls-lsd-oper&revision=2020-11-22
# http://cisco.com/ns/yang/Cisco-IOS-XR-es-acl-oper?module=Cisco-IOS-XR-es-acl-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-dwdm-ui-oper?module=Cisco-IOS-XR-dwdm-ui-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-aaa-locald-oper?module=Cisco-IOS-XR-aaa-locald-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-infra-ceredundancymib-cfg?module=Cisco-IOS-XR-infra-ceredundancymib-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-l2vpn-oper?module=Cisco-IOS-XR-l2vpn-oper&revision=2020-05-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-eigrp-cfg?module=Cisco-IOS-XR-eigrp-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-platform-oper?module=Cisco-IOS-XR-platform-oper&revision=2020-07-07
# http://cisco.com/ns/yang/Cisco-IOS-XR-telemetry-model-driven-cfg?module=Cisco-IOS-XR-telemetry-model-driven-cfg&revision=2020-12-11
# http://cisco.com/ns/yang/Cisco-IOS-XR-infra-script-mgmt-cfg?module=Cisco-IOS-XR-infra-script-mgmt-cfg&revision=2021-12-07
# http://cisco.com/ns/yang/Cisco-IOS-XR-tamsvcs-oper?module=Cisco-IOS-XR-tamsvcs-oper&revision=2020-11-15
# http://cisco.com/ns/yang/Cisco-IOS-XR-crypto-cepki-oper?module=Cisco-IOS-XR-crypto-cepki-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-bundlemgr-cfg?module=Cisco-IOS-XR-bundlemgr-cfg&revision=2021-02-08
# http://cisco.com/ns/yang/Cisco-IOS-XR-snmp-ifmib-cfg?module=Cisco-IOS-XR-snmp-ifmib-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-controller-odu-cfg?module=Cisco-IOS-XR-controller-odu-cfg&revision=2020-09-25
# http://cisco.com/ns/yang/Cisco-IOS-XR-tunnel-vpdn-oper?module=Cisco-IOS-XR-tunnel-vpdn-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-um-ipv6-access-list-cfg?module=Cisco-IOS-XR-um-ipv6-access-list-cfg&revision=2021-03-17&features=ipv6_acl_object_groups_supported,ipv6_acl_counter_supported,ipv6_acl_protocol_range_implemented,ipv6_acl_abf_implemented,ipv6_acl_abf_track_implemented,ipv6_acl_rollback_permit_supported,IP_ACL_TCP_URG_FLAG_IMPLEMENTED,IP_ACL_TCP_FLEXFLAGS_IMPLEMENTED,ipv6_acl_pktlen_implemented,ipv6_acl_is_udf_supported,ipv6_acl_capture_implemented,ipv6_acl_is_set_action_supported,ipv6_acl_is_set_qos_group_supported,ipv6_acl_is_set_ttl_supported,ipv6_acl_undetermined_transport_supported
# http://cisco.com/ns/yang/Cisco-IOS-XR-rgmgr-cfg?module=Cisco-IOS-XR-rgmgr-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-wanphy-ui-cfg?module=Cisco-IOS-XR-wanphy-ui-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-tunnel-l2tun-proto-mibs-cfg?module=Cisco-IOS-XR-tunnel-l2tun-proto-mibs-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-subscriber-pppoe-ma-gbl-cfg?module=Cisco-IOS-XR-subscriber-pppoe-ma-gbl-cfg&revision=2019-10-07
# http://cisco.com/ns/yang/Cisco-IOS-XR-infra-rcmd-oper?module=Cisco-IOS-XR-infra-rcmd-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-iedge4710-cfg?module=Cisco-IOS-XR-iedge4710-cfg&revision=2020-10-14
# http://cisco.com/ns/yang/Cisco-IOS-XR-tunnel-gre-datatypes?module=Cisco-IOS-XR-tunnel-gre-datatypes&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-l2-eth-infra-datatypes?module=Cisco-IOS-XR-l2-eth-infra-datatypes&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-ip-rip-oper?module=Cisco-IOS-XR-ip-rip-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-infra-rsi-cfg?module=Cisco-IOS-XR-infra-rsi-cfg&revision=2020-08-12
# http://cisco.com/ns/yang/Cisco-IOS-XR-um-if-l2transport-cfg?module=Cisco-IOS-XR-um-if-l2transport-cfg&revision=2020-02-10
# http://cisco.com/ns/yang/Cisco-IOS-XR-subscriber-session-mon-oper?module=Cisco-IOS-XR-subscriber-session-mon-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-infra-alarm-logger-oper?module=Cisco-IOS-XR-infra-alarm-logger-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-aaa-protocol-radius-oper?module=Cisco-IOS-XR-aaa-protocol-radius-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-evpn-oper?module=Cisco-IOS-XR-evpn-oper&revision=2021-05-12
# http://cisco.com/ns/yang/Cisco-IOS-XR-wanphy-ui-oper?module=Cisco-IOS-XR-wanphy-ui-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-wd-oper?module=Cisco-IOS-XR-wd-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-aaa-lib-datatypes?module=Cisco-IOS-XR-aaa-lib-datatypes&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-um-router-mld-cfg?module=Cisco-IOS-XR-um-router-mld-cfg&revision=2021-01-28
# http://cisco.com/ns/yang/Cisco-IOS-XR-flowspec-oper?module=Cisco-IOS-XR-flowspec-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-ifmgr-oper?module=Cisco-IOS-XR-ifmgr-oper&revision=2020-10-01
# http://cisco.com/ns/yang/Cisco-IOS-XR-li-cfg?module=Cisco-IOS-XR-li-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-snmp-sensormib-oper?module=Cisco-IOS-XR-snmp-sensormib-oper&revision=2020-05-15
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-igmp-oper?module=Cisco-IOS-XR-ipv4-igmp-oper&revision=2019-10-31
# http://cisco.com/ns/yang/Cisco-IOS-XR-subscriber-srg-cfg?module=Cisco-IOS-XR-subscriber-srg-cfg&revision=2020-11-25
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-mfwd-cfg?module=Cisco-IOS-XR-ipv4-mfwd-cfg&revision=2020-04-02
# http://cisco.com/ns/yang/Cisco-IOS-XR-plat-chas-invmgr-ng-oper?module=Cisco-IOS-XR-plat-chas-invmgr-ng-oper&revision=2020-05-14
# http://cisco.com/ns/yang/Cisco-IOS-XR-clns-isis-cfg?module=Cisco-IOS-XR-clns-isis-cfg&revision=2021-02-07
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-ma-cfg?module=Cisco-IOS-XR-ipv4-ma-cfg&revision=2019-04-05
# urn:ietf:params:xml:ns:yang:ietf-yang-types?module=ietf-yang-types&revision=2013-07-15
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-hsrp-oper?module=Cisco-IOS-XR-ipv4-hsrp-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-spirit-install-instmgr-oper?module=Cisco-IOS-XR-spirit-install-instmgr-oper&revision=2020-10-06
# http://cisco.com/ns/yang/Cisco-IOS-XR-crypto-sam-cfg?module=Cisco-IOS-XR-crypto-sam-cfg&revision=2020-07-12
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-vrrp-cfg?module=Cisco-IOS-XR-ipv4-vrrp-cfg&revision=2019-11-29
# http://cisco.com/ns/yang/Cisco-IOS-XR-ip-iep-oper?module=Cisco-IOS-XR-ip-iep-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-pbr-cfg?module=Cisco-IOS-XR-pbr-cfg&revision=2020-11-19
# http://cisco.com/ns/yang/Cisco-IOS-XR-lpts-pre-ifib-act?module=Cisco-IOS-XR-lpts-pre-ifib-act&revision=2020-09-20
# http://cisco.com/ns/yang/Cisco-IOS-XR-snmp-entitymib-oper?module=Cisco-IOS-XR-snmp-entitymib-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-telemetry-model-driven-oper?module=Cisco-IOS-XR-telemetry-model-driven-oper&revision=2021-09-13
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv6-ospfv3-act?module=Cisco-IOS-XR-ipv6-ospfv3-act&revision=2020-08-13
# http://cisco.com/ns/yang/Cisco-IOS-XR-invmgr-oper?module=Cisco-IOS-XR-invmgr-oper&revision=2020-07-24
# http://cisco.com/ns/yang/Cisco-IOS-XR-ip-ntp-cfg?module=Cisco-IOS-XR-ip-ntp-cfg&revision=2019-10-31
# http://cisco.com/ns/yang/Cisco-IOS-XR-um-if-tunnel-cfg?module=Cisco-IOS-XR-um-if-tunnel-cfg&revision=2019-06-10
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-acl-cfg?module=Cisco-IOS-XR-ipv4-acl-cfg&revision=2021-03-17
# http://cisco.com/ns/yang/Cisco-IOS-XR-man-ipsla-cfg?module=Cisco-IOS-XR-man-ipsla-cfg&revision=2019-05-10
# http://cisco.com/ns/yang/Cisco-IOS-XR-man-ipsla-oper?module=Cisco-IOS-XR-man-ipsla-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-aaa-diameter-cfg?module=Cisco-IOS-XR-aaa-diameter-cfg&revision=2020-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-io-cfg?module=Cisco-IOS-XR-ipv4-io-cfg&revision=2020-02-18
# http://cisco.com/ns/yang/Cisco-IOS-XR-ipv6-ma-oper?module=Cisco-IOS-XR-ipv6-ma-oper&revision=2020-09-03
# http://cisco.com/ns/yang/Cisco-IOS-XR-ip-rib-ipv6-oper?module=Cisco-IOS-XR-ip-rib-ipv6-oper&revision=2020-12-11
# http://cisco.com/ns/yang/Cisco-IOS-XR-mpls-ldp-cfg?module=Cisco-IOS-XR-mpls-ldp-cfg&revision=2021-07-16
# http://cisco.com/ns/yang/Cisco-IOS-XR-snmp-mib-rfmib-cfg?module=Cisco-IOS-XR-snmp-mib-rfmib-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-lib-mpp-oper?module=Cisco-IOS-XR-lib-mpp-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-cfgmgr-clear-inconsistency-act?module=Cisco-IOS-XR-cfgmgr-clear-inconsistency-act&revision=2020-09-10
# http://cisco.com/ns/yang/Cisco-IOS-XR-um-mpls-ldp-cfg?module=Cisco-IOS-XR-um-mpls-ldp-cfg&revision=2021-01-29
# http://cisco.com/ns/yang/Cisco-IOS-XR-mpls-lsd-cfg?module=Cisco-IOS-XR-mpls-lsd-cfg&revision=2020-07-29
# http://cisco.com/ns/yang/Cisco-IOS-XR-invproxy-hwmodule-cfg?module=Cisco-IOS-XR-invproxy-hwmodule-cfg&revision=2020-12-19
# http://cisco.com/ns/yang/Cisco-IOS-XR-opticalotsmib-cfg?module=Cisco-IOS-XR-opticalotsmib-cfg&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-perf-meas-oper?module=Cisco-IOS-XR-perf-meas-oper&revision=2021-06-02
# http://cisco.com/ns/yang/Cisco-IOS-XR-mpls-static-oper?module=Cisco-IOS-XR-mpls-static-oper&revision=2019-04-05
# http://cisco.com/ns/yang/Cisco-IOS-XR-mpls-ping-act?module=Cisco-IOS-XR-mpls-ping-act&revision=2021-04-27
# http://cisco.com/ns/yang/Cisco-IOS-XR-um-if-vrf-cfg?module=Cisco-IOS-XR-um-if-vrf-cfg&revision=2019-10-10
# ...
# http://cisco.com/ns/yang/Cisco-IOS-XR-hw-module-cfg-deviations?module=Cisco-IOS-XR-hw-module-cfg-deviations&revision=2020-05-27
# http://www.cisco.com/ns/yang/Cisco-IOS-XR-sysadmin-sm-hw-mod?module=Cisco-IOS-XR-sysadmin-sm-hw-mod&revision=2020-08-12
# http://www.cisco.com/ns/yang/Cisco-IOS-XR-sysadmin-hw-module-xrv9k?module=Cisco-IOS-XR-sysadmin-hw-module-xrv9k&revision=2019-04-15
# urn:ietf:params:xml:ns:yang:iana-crypt-hash?module=iana-crypt-hash&revision=2014-08-06
# http://www.cisco.com/ns/yang/Cisco-IOS-XR-sysadmin-aaa-aaa-show?module=Cisco-IOS-XR-sysadmin-aaa-aaa-show&revision=2019-04-15
# http://tail-f.com/ns/mibs/INET-ADDRESS-MIB/200205090000Z?module=INET-ADDRESS-MIB&revision=2002-05-09
# http://www.cisco.com/ns/yang/Cisco-IOS-XR-sysadmin-cm?module=Cisco-IOS-XR-sysadmin-cm&revision=2019-04-15
# http://www.cisco.com/ns/yang/Cisco-IOS-XR-sysadmin-aaa-disaster-recovery?module=Cisco-IOS-XR-sysadmin-aaa-disaster-recovery&revision=2019-04-15
# http://cisco.com/calvados/Cisco-IOS-XR-sysadmin-issu?module=Cisco-IOS-XR-sysadmin-issu&revision=2019-06-12
# http://www.cisco.com/ns/yang/Cisco-IOS-XR-sysadmin-sm-system-cluster?module=Cisco-IOS-XR-sysadmin-sm-system-cluster&revision=2020-09-01
# http://www.cisco.com/ns/yang/Cisco-IOS-XR-sysadmin-ds?module=Cisco-IOS-XR-sysadmin-ds&revision=2019-10-31
# http://www.cisco.com/ns/yang/Cisco-IOS-XR-sysadmin-tacacs-show-tacacs?module=Cisco-IOS-XR-sysadmin-tacacs-show-tacacs&revision=2019-04-15
# http://www.cisco.com/ns/yang/Cisco-IOS-XR-sysadmin-fpd-infra-cli-fpdserv-ctrace?module=Cisco-IOS-XR-sysadmin-fpd-infra-cli-fpdserv-ctrace&revision=2019-04-15
# http://www.cisco.com/ns/yang/Cisco-IOS-XR-sysadmin-entity-state-mib?module=Cisco-IOS-XR-sysadmin-entity-state-mib&revision=2019-04-15
# http://tail-f.com/yang/common-monitoring?module=tailf-common-monitoring&revision=2013-06-14
# http://www.cisco.com/ns/yang/Cisco-IOS-XR-sysadmin-show-inv?module=Cisco-IOS-XR-sysadmin-show-inv&revision=2019-04-15
# http://www.cisco.com/ns/yang/Cisco-IOS-XR-sysadmin-entity-sensor-mib?module=Cisco-IOS-XR-sysadmin-entity-sensor-mib&revision=2019-04-15
# http://www.cisco.com/ns/yang/Cisco-IOS-XR-sysadmin-show-trace-debug-agent?module=Cisco-IOS-XR-sysadmin-show-trace-debug-agent&revision=2019-04-15
# http://www.cisco.com/ns/yang/Cisco-IOS-XR-sysadmin-show-trace-cm?module=Cisco-IOS-XR-sysadmin-show-trace-cm&revision=2019-04-15
# http://tail-f.com/ns/mibs/SNMPv2-SMI/1.0?module=SNMPv2-SMI&revision=1998-09-18
# http://www.cisco.com/ns/yang/Cisco-IOS-XR-sysadmin-tacacs-test-tacacs?module=Cisco-IOS-XR-sysadmin-tacacs-test-tacacs&revision=2021-02-26
# http://www.cisco.com/ns/yang/Cisco-IOS-XR-sysadmin-syslog?module=Cisco-IOS-XR-sysadmin-syslog&revision=2019-04-15
# http://www.cisco.com/ns/yang/Cisco-IOS-XR-sysadmin-show-trace-instagt?module=Cisco-IOS-XR-sysadmin-show-trace-instagt&revision=2019-04-15
# http://www.cisco.com/ns/yang/Cisco-IOS-XR-sysadmin-sm?module=Cisco-IOS-XR-sysadmin-sm&revision=2020-09-01
# http://cisco.com/ns/yang/cisco-xr-ietf-yang-library-deviations?module=cisco-xr-ietf-yang-library-deviations&revision=2019-10-21
# http://tail-f.com/ns/mibs/SNMP-FRAMEWORK-MIB/200210140000Z?module=SNMP-FRAMEWORK-MIB&revision=2002-10-14
# http://www.cisco.com/ns/yang/Cisco-IOS-XR-sysadmin-entity-state-tc-mib?module=Cisco-IOS-XR-sysadmin-entity-state-tc-mib&revision=2019-04-15
# urn:ietf:params:xml:ns:yang:ietf-yang-library?module=ietf-yang-library&revision=2019-01-04&deviations=cisco-xr-ietf-yang-library-deviations
# http://www.cisco.com/ns/yang/Cisco-IOS-XR-sysadmin-obfl-conf?module=Cisco-IOS-XR-sysadmin-obfl-conf&revision=2019-04-15
# http://www.cisco.com/ns/yang/Cisco-IOS-XR-sysadmin-rvm-mgr?module=Cisco-IOS-XR-sysadmin-rvm-mgr&revision=2020-04-09
# http://cisco.com/panini/calvados/fit?module=fit&revision=2018-06-16
# http://www.cisco.com/ns/yang/Cisco-IOS-XR-sysadmin-debug-trace?module=Cisco-IOS-XR-sysadmin-debug-trace&revision=2019-06-24
# http://www.cisco.com/ns/yang/Cisco-IOS-XR-sysadmin-show-trace?module=Cisco-IOS-XR-sysadmin-show-trace&revision=2019-04-15
# http://www.cisco.com/ns/yang/Cisco-IOS-XR-sysadmin-fpd-infra-cli-fpd?module=Cisco-IOS-XR-sysadmin-fpd-infra-cli-fpd&revision=2019-04-15
# http://tail-f.com/ns/mibs/SNMP-NOTIFICATION-MIB/200210140000Z?module=SNMP-NOTIFICATION-MIB&revision=2021-03-15
# http://www.cisco.com/ns/yang/Cisco-IOS-XR-sysadmin-fpd-infra-cli-fpd-service?module=Cisco-IOS-XR-sysadmin-fpd-infra-cli-fpd-service&revision=2019-04-15
# http://www.cisco.com/ns/yang/Cisco-IOS-XR-sysadmin-wdmon?module=Cisco-IOS-XR-sysadmin-wdmon&revision=2019-04-15
# http://tail-f.com/ns/mibs/SNMP-TARGET-MIB/200210140000Z?module=SNMP-TARGET-MIB&revision=2002-10-14
# http://tail-f.com/ns/mibs/SNMP-VIEW-BASED-ACM-MIB/200210160000Z?module=SNMP-VIEW-BASED-ACM-MIB&revision=2002-10-16
# http://www.cisco.com/ns/yang/Cisco-IOS-XR-sysadmin-services?module=Cisco-IOS-XR-sysadmin-services&revision=2019-04-15
# urn:ietf:params:xml:ns:yang:ietf-netconf-monitoring?module=ietf-netconf-monitoring&revision=2010-10-04&deviations=cisco-xr-ietf-netconf-monitoring-deviations
# http://www.cisco.com/panini/calvados/valtest?module=valtest&revision=2012-08-20
# http://tail-f.com/ns/mibs/SNMP-COMMUNITY-MIB/200308060000Z?module=SNMP-COMMUNITY-MIB&revision=2003-08-06
# http://tail-f.com/ns/netconf/actions/1.0?module=tailf-actions&revision=2017-02-28
# http://tail-f.com/ns/mibs/CISCO-ENTITY-FRU-CONTROL-MIB/200311240000Z?module=CISCO-ENTITY-FRU-CONTROL-MIB&revision=2003-11-24
# http://www.cisco.com/ns/yang/Cisco-IOS-XR-sysadmin-show-media?module=Cisco-IOS-XR-sysadmin-show-media&revision=2020-06-04
# http://www.cisco.com/ns/yang/Cisco-IOS-XR-sysadmin-show-obfl?module=Cisco-IOS-XR-sysadmin-show-obfl&revision=2019-04-15
# urn:ietf:params:xml:ns:yang:ietf-datastores?module=ietf-datastores&revision=2018-02-14
# http://www.cisco.com/ns/yang/Cisco-IOS-XR-sysadmin-show-diag?module=Cisco-IOS-XR-sysadmin-show-diag&revision=2019-04-15
# http://tail-f.com/ns/mibs/SNMPv2-TC/1.0?module=SNMPv2-TC&revision=2016-08-18
# http://www.cisco.com/ns/yang/Cisco-IOS-XR-sysadmin-aaa-command-accounting?module=Cisco-IOS-XR-sysadmin-aaa-command-accounting&revision=2019-11-15
# http://cisco.com/ns/yang/cisco-xr-ietf-netconf-acm-deviations?module=cisco-xr-ietf-netconf-acm-deviations&revision=2017-08-02
# http://www.cisco.com/ns/yang/Cisco-IOS-XR-sysadmin-system?module=Cisco-IOS-XR-sysadmin-system&revision=2019-04-15
# http://www.cisco.com/ns/yang/Cisco-IOS-XR-sysadmin-vm?module=Cisco-IOS-XR-sysadmin-vm&revision=2019-04-15
# http://openconfig.net/yang/isis-lsdb-types?module=openconfig-isis-lsdb-types&revision=2018-11-21
# http://openconfig.net/yang/system/procmon?module=openconfig-procmon&revision=2017-09-18
# http://openconfig.net/yang/openconfig-isis?module=openconfig-isis&revision=2018-11-21
# http://openconfig.net/yang/openconfig-ext?module=openconfig-extensions&revision=2018-10-17
# http://openconfig.net/yang/bgp-policy?module=openconfig-bgp-policy&revision=2017-07-30&deviations=cisco-xr-openconfig-bgp-policy-deviations
# http://openconfig.net/yang/telemetry?module=openconfig-telemetry&revision=2016-02-04&deviations=cisco-xr-openconfig-telemetry-deviations
# http://openconfig.net/yang/types/yang?module=openconfig-yang-types&revision=2018-04-24
# http://openconfig.net/yang/system/logging?module=openconfig-system-logging&revision=2017-09-18
# http://openconfig.net/yang/platform/fan?module=openconfig-platform-fan&revision=2018-11-21
# http://openconfig.net/yang/alarms?module=openconfig-alarms&revision=2018-01-16
# http://openconfig.net/yang/platform/port?module=openconfig-platform-port&revision=2018-01-20&deviations=cisco-xr-openconfig-platform-port-deviations
# http://openconfig.net/yang/vlan?module=openconfig-vlan&revision=2016-05-26&deviations=cisco-xr-openconfig-vlan-deviations
# http://openconfig.net/yang/network-instance-types?module=openconfig-network-instance-types&revision=2016-12-15
# http://openconfig.net/yang/platform/transceiver?module=openconfig-platform-transceiver&revision=2018-11-25&deviations=cisco-xr-openconfig-platform-transceiver-deviations
# http://openconfig.net/yang/interfaces/ip?module=openconfig-if-ip&revision=2019-01-08&deviations=cisco-xr-openconfig-if-ip-deviations
# http://openconfig.net/yang/interfaces/tunnel?module=openconfig-if-tunnel&revision=2018-11-21
# http://openconfig.net/yang/interfaces/aggregate?module=openconfig-if-aggregate&revision=2016-05-26
# http://openconfig.net/yang/transport-types?module=openconfig-transport-types&revision=2019-06-27
# http://openconfig.net/yang/rib/bgp?module=openconfig-rib-bgp&revision=2016-04-11&deviations=cisco-xr-openconfig-rib-bgp-deviations
# http://openconfig.net/yang/network-instance-l3?module=openconfig-network-instance-l3&revision=2017-01-13
# http://openconfig.net/yang/types/inet?module=openconfig-inet-types&revision=2017-08-24
# http://openconfig.net/yang/interfaces/ethernet?module=openconfig-if-ethernet&revision=2020-05-06&deviations=cisco-xr-openconfig-if-ethernet-deviations
# http://openconfig.net/yang/rib/bgp-types?module=openconfig-rib-bgp-types&revision=2016-04-11
# http://openconfig.net/yang/aft?module=openconfig-aft&revision=2017-05-10
# http://openconfig.net/yang/policy-types?module=openconfig-policy-types&revision=2017-07-14
# http://openconfig.net/yang/lldp?module=openconfig-lldp&revision=2016-05-16&deviations=cisco-xr-openconfig-lldp-deviations
# http://openconfig.net/yang/system/terminal?module=openconfig-system-terminal&revision=2017-09-18
# http://openconfig.net/yang/network-instance?module=openconfig-network-instance&revision=2017-01-13&deviations=cisco-xr-openconfig-network-instance-deviations
# http://openconfig.net/yang/bgp-types?module=openconfig-bgp-types&revision=2017-02-02
# http://openconfig.net/yang/system?module=openconfig-system&revision=2018-07-17&deviations=cisco-xr-openconfig-system-deviations
# http://openconfig.net/yang/packet-match-types?module=openconfig-packet-match-types&revision=2017-05-26
# http://openconfig.net/yang/lacp?module=openconfig-lacp&revision=2017-05-05&deviations=cisco-xr-openconfig-lacp-deviations
# http://openconfig.net/yang/interfaces/ethernet-ext?module=openconfig-if-ethernet-ext&revision=2018-11-21
# http://openconfig.net/yang/bfd?module=openconfig-bfd&revision=2018-11-21
# http://openconfig.net/yang/rsvp-sr-ext?module=openconfig-rsvp-sr-ext&revision=2017-03-06&deviations=cisco-xr-openconfig-rsvp-sr-ext-deviations
# http://openconfig.net/yang/platform/psu?module=openconfig-platform-psu&revision=2018-11-21&deviations=cisco-xr-openconfig-platform-psu-deviations
# http://openconfig.net/yang/vlan-types?module=openconfig-vlan-types&revision=2016-05-26
# http://openconfig.net/yang/isis-types?module=openconfig-isis-types&revision=2018-11-21
# http://openconfig.net/yang/platform/cpu?module=openconfig-platform-cpu&revision=2018-01-30&deviations=cisco-xr-openconfig-platform-cpu-deviations
# http://openconfig.net/yang/lldp/types?module=openconfig-lldp-types&revision=2016-05-16
# http://openconfig.net/yang/openconfig-types?module=openconfig-types&revision=2019-04-16
# http://openconfig.net/yang/fib-types?module=openconfig-aft-types&revision=2017-05-10
# http://openconfig.net/yang/aaa?module=openconfig-aaa&revision=2018-04-12
# http://openconfig.net/yang/platform/linecard?module=openconfig-platform-linecard&revision=2018-11-21
# http://openconfig.net/yang/header-fields?module=openconfig-packet-match&revision=2017-05-26
# http://openconfig.net/yang/openconfig-if-types?module=openconfig-if-types&revision=2018-01-05
# http://openconfig.net/yang/platform/extension?module=openconfig-platform-ext&revision=2018-11-21
# http://openconfig.net/yang/aaa/types?module=openconfig-aaa-types&revision=2018-04-12
# http://openconfig.net/yang/aft/ni?module=openconfig-aft-network-instance&revision=2017-01-13
# http://openconfig.net/yang/platform?module=openconfig-platform&revision=2019-04-16&deviations=cisco-xr-openconfig-platform-deviations
# http://openconfig.net/yang/routing-policy?module=openconfig-routing-policy&revision=2018-06-05
# http://openconfig.net/yang/interfaces?module=openconfig-interfaces&revision=2019-11-19&deviations=cisco-xr-openconfig-interfaces-deviations
# http://openconfig.net/yang/acl?module=openconfig-acl&revision=2017-05-26&deviations=cisco-xr-openconfig-acl-deviations
# http://openconfig.net/yang/alarms/types?module=openconfig-alarm-types&revision=2018-01-16
# http://openconfig.net/yang/system/management?module=openconfig-system-management&revision=2018-08-28
# http://openconfig.net/yang/openconfig-isis-policy?module=openconfig-isis-policy&revision=2018-11-21
# http://openconfig.net/yang/interfaces/ip-ext?module=openconfig-if-ip-ext&revision=2018-11-21&deviations=cisco-xr-openconfig-if-ip-ext-deviations
# http://openconfig.net/yang/platform-types?module=openconfig-platform-types&revision=2019-06-03
# http://cisco.com/ns/yang/cisco-xr-openconfig-local-routing-deviations?module=cisco-xr-openconfig-local-routing-deviations&revision=2017-06-28
# http://cisco.com/ns/yang/cisco-xr-openconfig-platform-cpu-deviations?module=cisco-xr-openconfig-platform-cpu-deviations&revision=2018-12-10
# http://cisco.com/ns/yang/cisco-xr-openconfig-if-ip-deviations?module=cisco-xr-openconfig-if-ip-deviations&revision=2017-02-07
# http://cisco.com/ns/yang/cisco-xr-openconfig-platform-transceiver-deviations?module=cisco-xr-openconfig-platform-transceiver-deviations&revision=2019-09-05
# http://cisco.com/ns/yang/cisco-xr-openconfig-telemetry-deviations?module=cisco-xr-openconfig-telemetry-deviations&revision=2017-03-09
# http://cisco.com/ns/yang/cisco-xr-openconfig-alarms-deviations?module=cisco-xr-openconfig-alarms-deviations&revision=2019-11-14
# http://cisco.com/ns/yang/cisco-xr-openconfig-isis-policy-deviations?module=cisco-xr-openconfig-isis-policy-deviations&revision=2019-06-10
# http://cisco.com/ns/yang/cisco-xr-openconfig-if-tunnel-deviations?module=cisco-xr-openconfig-if-tunnel-deviations&revision=2020-03-20
# http://cisco.com/ns/yang/cisco-xr-openconfig-if-ip-ext-deviations?module=cisco-xr-openconfig-if-ip-ext-deviations&revision=2019-09-13
# http://cisco.com/ns/yang/cisco-xr-openconfig-system-deviations?module=cisco-xr-openconfig-system-deviations&revision=2018-12-12
# http://cisco.com/ns/yang/cisco-xr-openconfig-platform-port-deviations?module=cisco-xr-openconfig-platform-port-deviations&revision=2018-12-10
# http://cisco.com/ns/yang/cisco-xr-openconfig-interfaces-deviations?module=cisco-xr-openconfig-interfaces-deviations&revision=2016-05-16
# http://cisco.com/ns/yang/cisco-xr-openconfig-bfd-deviations?module=cisco-xr-openconfig-bfd-deviations&revision=2019-05-06
# http://cisco.com/ns/yang/cisco-xr-openconfig-bgp-policy-deviations?module=cisco-xr-openconfig-bgp-policy-deviations&revision=2019-08-31
# http://cisco.com/ns/yang/cisco-xr-openconfig-vlan-deviations?module=cisco-xr-openconfig-vlan-deviations&revision=2019-04-18
# http://cisco.com/ns/yang/cisco-xr-openconfig-acl-deviations?module=cisco-xr-openconfig-acl-deviations&revision=2018-02-07
# http://cisco.com/ns/yang/cisco-xr-openconfig-routing-policy-deviations?module=cisco-xr-openconfig-routing-policy-deviations&revision=2019-02-06
# http://cisco.com/ns/yang/cisco-xr-openconfig-lacp-deviations?module=cisco-xr-openconfig-lacp-deviations&revision=2019-09-10
# http://cisco.com/ns/yang/cisco-xr-openconfig-platform-psu-deviations?module=cisco-xr-openconfig-platform-psu-deviations&revision=2018-12-10
# http://cisco.com/ns/yang/cisco-xr-openconfig-network-instance-deviations?module=cisco-xr-openconfig-network-instance-deviations&revision=2019-10-23
# http://cisco.com/ns/yang/cisco-xr-openconfig-rsvp-sr-ext-deviations?module=cisco-xr-openconfig-rsvp-sr-ext-deviations&revision=2019-05-30
# http://cisco.com/ns/yang/cisco-xr-openconfig-lldp-deviations?module=cisco-xr-openconfig-lldp-deviations&revision=2017-03-08
# http://cisco.com/ns/yang/cisco-xr-openconfig-if-ethernet-deviations?module=cisco-xr-openconfig-if-ethernet-deviations&revision=2016-05-16
# http://cisco.com/ns/yang/cisco-xr-openconfig-rib-bgp-deviations?module=cisco-xr-openconfig-rib-bgp-deviations&revision=2016-10-16
# http://cisco.com/ns/yang/cisco-xr-openconfig-platform-deviations?module=cisco-xr-openconfig-platform-deviations&revision=2018-12-05

# %% [markdown]
# En efecto son muchos ... Sin embargo, para encontrar el modelo que configura las ACLs, podemos simplemente usar regex y filtrar la lista.

# %%
for c in xr.server_capabilities:
    model = re.search('module=([^&]*acl[^&]*)&', c)
    if model is not None:
        print(model.group(1))
# Out:
# Cisco-IOS-XR-ipv4-acl-datatypes
# Cisco-IOS-XR-ipv6-acl-datatypes
# Cisco-IOS-XR-ipv4-acl-oper
# Cisco-IOS-XR-ipv6-acl-cfg
# Cisco-IOS-XR-es-acl-datatypes
# Cisco-IOS-XR-common-acl-datatypes
# Cisco-IOS-XR-es-acl-cfg
# Cisco-IOS-XR-es-acl-oper
# Cisco-IOS-XR-ipv4-acl-cfg
# Cisco-IOS-XR-ipv6-acl-oper
# openconfig-acl
# cisco-xr-openconfig-acl-deviations

# %% [markdown]
# El modelo YANG que vamos a usar es ```Cisco-IOS-XR-ipv4-acl-cfg```. Los otros archivos tienen diferentes funciones, tal y como definiciones de estructuras de datos, configuraciones auxiliares, e incluso OpenConfig - que es una iniciativa Open Source para unificar los modelos de datos sin importar el fabricante (más información de este tema [aquí](https://github.com/ponchotitlan/oss-summit-OpenConfig-demo)).
#
# Los modelos de datos igual suelen ser publicados online por casi todos los fabricantes. En nuestro caso, el modelo de ACLs para Cisco IOSXR está igual disponible [en este repositorio público](https://github.com/YangModels/yang/blob/main/vendor/cisco/xr/2411/Cisco-IOS-XR-ipv4-acl-cfg.yang).

# %% [markdown]
# ### 🏗️ 2 - Hablando YANG con mi router
#
# Vamos ahora a explorar el contenido de este modelo de datos para las ACLs:

# %%
ACL_NATIVE_MODULE = 'Cisco-IOS-XR-ipv4-acl-cfg'

data_model_payload = xr.get_schema(ACL_NATIVE_MODULE)
print (data_model_payload.data)
# Out:
# module Cisco-IOS-XR-ipv4-acl-cfg {
#
#   /*** NAMESPACE / PREFIX DEFINITION ***/
#
#   namespace "http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-acl-cfg";
#
#
#   prefix "ipv4-acl-cfg";
#
#   /*** LINKAGE (IMPORTS / INCLUDES) ***/
#
#   import ietf-inet-types { prefix "inet"; }
#
#   import Cisco-IOS-XR-types { prefix "xr"; }
#
#   import cisco-semver { prefix "semver"; }
#
#   import Cisco-IOS-XR-ipv4-acl-datatypes { prefix "dt1"; }
#
#   include Cisco-IOS-XR-ipv4-ace-cfg {
#     revision-date 2021-03-17;
#   }
#
#   /*** META INFORMATION ***/
#
#   organization "Cisco Systems, Inc.";
#
#   contact
#     "Cisco Systems, Inc.
#      Customer Service
#
#      Postal: 170 West Tasman Drive
#      San Jose, CA 95134
#
#      Tel: +1 800 553-NETS
#
#      E-mail: cs-yang@cisco.com";
#
#   description
#     "This module contains a collection of YANG definitions
#      for Cisco IOS-XR ipv4-acl package configuration.
#
#      This module contains definitions
#      for the following management objects:
#        ipv4-acl-and-prefix-list: IPv4 ACL configuration data
#
#      Copyright (c) 2013-2021 by Cisco Systems, Inc.
#      All rights reserved.";
#
#   revision "2021-03-17" {
#     description
#       "7.3.15 revision. Adding vrrp and rsvp keywords for protocol under access-list config CLI.
#        2020-11-23
#          7.3.2 revision. Changing the bag version";
#     semver:module-version "1.1.1";
#   }
#
#   revision "2019-10-22" {
#     description
#       "7.0.1 revision. Fixing ICMP TYPE CODE datatype from Enum to RangeEnum";
#     semver:module-version "1.1.1";
#   }
#
#   revision "2019-04-05" {
#     description
#       "Establish semantic version baseline.";
#     semver:module-version "1.0.0";
#   }
#
#   revision "2018-05-08" {
#     description
#       "6.5.1 revision. Remove the when statement for fragments.";
#   }
#
#   revision "2018-04-03" {
#     description
#       "6.5.1 revision. Correct enum value for Next-hop-type.";
#   }
#
#   revision "2018-03-23" {
#     description
#       "6.5.1 revision. Removing none-next-type.";
#   }
#
#   revision "2018-02-01" {
#     description
#       "Using YANG bit types for tcp flags.";
#   }
#
#   revision "2018-01-03" {
#     description
#       "6.4.1 revision. Fixed a few typos in the description.";
#   }
#
#   revision "2017-10-15" {
#     description
#       "Removed presence statement generated from internal CLI data.";
#   }
#
#   revision "2015-11-09" {
#     description
#       "IOS XR 6.0 revision.";
#   }
#
#   container ipv4-acl-and-prefix-list {
#     description "IPv4 ACL configuration data";
#
#     container accesses {
#       description
#         "Table of access lists.  Entries in this table
#         and the AccessListExistenceTable table must be
#         kept consistent";
#
#       list access {
#         key "access-list-name";
#         description "An ACL";
#
#         container access-list-entries {
#           description "ACL entry table; contains list of ACEs";
#
#           list access-list-entry {
#             key "sequence-number";
#             description
#               "An ACL entry; either a description (remark)
#               or an ACE to match against";
#             leaf sequence-number {
#               type dt1:Ipv4-acl-sequence-number-range-acl;
#               description "Sequence number for this entry";
#             }
#             uses IPV4-ACE;
#           }
#         }
#         leaf access-list-name {
#           type xr:Cisco-ios-xr-string {
#             length "1..64";
#           }
#           description "Access list name - 64 characters max";
#         }
#       }
#     }
#
#     container prefixes {
#       description
#         "Table of ACL prefix lists.  Entries in this
#         table and the PrefixListExistenceTable table
#         must be kept consistent";
#
#       list prefix {
#         key "prefix-list-name";
#         description "Name of a prefix list";
#
#         container prefix-list-entries {
#           description "Sequence of entries forming a prefix list";
#
#           list prefix-list-entry {
#             key "sequence-number";
#             description
#               "A prefix list entry; either a description
#               (remark) or a prefix to match against";
#             leaf sequence-number {
#               type dt1:Ipv4-acl-sequence-number-range;
#               description "Sequence number of prefix list";
#             }
#             leaf grant {
#               type dt1:Ipv4-acl-grant-enum;
#               description
#                 "Whether to forward or drop packets matching
#                 the prefix list";
#             }
#             leaf prefix {
#               type inet:ipv4-address-no-zone;
#               description "IPv4 address prefix to match";
#             }
#             leaf netmask {
#               type inet:ipv4-address-no-zone;
#               description "Mask of IPv4 address prefix";
#             }
#             leaf match-exact-length {
#               type empty;
#               description
#                 "Set to perform an exact prefix length match.
#                 Item is mutually exclusive with minimum and
#                 maximum length match items";
#             }
#             leaf exact-prefix-length {
#               type dt1:Ipv4-acl-prefix-length-range;
#               description
#                 "If exact prefix length matching specified,
#                 set the length of prefix to be matched";
#             }
#             leaf match-max-length {
#               type empty;
#               description
#                 "Set to perform a maximum length prefix match
#                 .  Item is mutually exclusive with exact
#                 length match item";
#             }
#             leaf max-prefix-length {
#               type dt1:Ipv4-acl-prefix-length-range;
#               description
#                 "If maximum length prefix matching specified,
#                 set the maximum length of prefix to be
#                 matched";
#             }
#             leaf match-min-length {
#               type empty;
#               description
#                 "Set to perform a minimum length prefix match
#                 .  Item is mutually exclusive with exact
#                 length match item";
#             }
#             leaf min-prefix-length {
#               type dt1:Ipv4-acl-prefix-length-range;
#               description
#                 "If minimum length prefix matching specified,
#                 set the minimum length of prefix to be
#                 matched";
#             }
#             leaf remark {
#               type string;
#               description
#                 "Comments or a description for the prefix
#                 list.  Item is mutually exclusive with all
#                 others in the object";
#             }
#           }
#         }
#         leaf prefix-list-name {
#           type string;
#           description "Prefix list name - max 32 characters";
#         }
#       }
#     }
#
#     container log-update {
#       description "Control access lists log updates";
#       leaf threshold {
#         type dt1:Ipv4-acl-log-threshold-range;
#         description "Log update threshold (number of hits)";
#       }
#       leaf rate {
#         type dt1:Ipv4-acl-log-rate-range;
#         description "Log update rate (log msgs per second)";
#       }
#     }
#   }
# }

# %% [markdown]
# A veces, no es fácil leer un modelo de datos con la sintaxis en YANG, especialmente cuando el modelo es extenso y tiene muchas estructuras. La herramienta ```pyang``` permite la visualización de la estructura de forma gráfica.
#
# En este ejemplo, vamos a guardar nuestro modelo de datos en un archivo y luego generar el gráfico para una mejor visualización. (Ojo, que vamos a necesitar usar también otros archivos que son dependencias).

# %%
ACL_YANG_DEPENDENCIES = ['Cisco-IOS-XR-types', 'cisco-semver', 'Cisco-IOS-XR-ipv4-acl-datatypes', 'Cisco-IOS-XR-ipv4-ace-cfg']

for dependency in ACL_YANG_DEPENDENCIES:
    with open(f"{dependency}.yang", "w") as f:
        f.write(xr.get_schema(dependency).data)

with open(f"{ACL_NATIVE_MODULE}.yang", "w") as f:
    f.write(data_model_payload.data)
    
# !pyang -f tree Cisco-IOS-XR-ipv4-acl-cfg.yang
# Out:
# module: Cisco-IOS-XR-ipv4-acl-cfg
#   +--rw ipv4-acl-and-prefix-list
#      +--rw accesses
#      |  +--rw access* [access-list-name]
#      |     +--rw access-list-entries
#      |     |  +--rw access-list-entry* [sequence-number]
#      |     |     +--rw sequence-number             dt1:Ipv4-acl-sequence-number-range-acl
#      |     |     +--rw grant?                      ipv4-acl-dt:Ipv4-acl-grant-enum
#      |     |     +--rw protocol-operator?          ipv4-acl-dt:Ipv4-acl-operator-enum
#      |     |     +--rw protocol?                   ipv4-acl-dt:Ipv4-acl-protocol-number
#      |     |     +--rw protocol2?                  ipv4-acl-dt:Ipv4-acl-protocol-number
#      |     |     +--rw source-network
#      |     |     |  +--rw source-address?          inet:ipv4-address-no-zone
#      |     |     |  +--rw source-wild-card-bits?   inet:ipv4-address-no-zone
#      |     |     |  +--rw source-prefix-length?    xr:Ipv4-prefix-length
#      |     |     +--rw destination-network
#      |     |     |  +--rw destination-address?          inet:ipv4-address-no-zone
#      |     |     |  +--rw destination-wild-card-bits?   inet:ipv4-address-no-zone
#      |     |     |  +--rw destination-prefix-length?    xr:Ipv4-prefix-length
#      |     |     +--rw source-port
#      |     |     |  +--rw source-operator?      ipv4-acl-dt:Ipv4-acl-operator-enum
#      |     |     |  +--rw first-source-port?    ipv4-acl-dt:Ipv4-acl-port-number
#      |     |     |  +--rw second-source-port?   ipv4-acl-dt:Ipv4-acl-port-number
#      |     |     +--rw destination-port
#      |     |     |  +--rw destination-operator?      ipv4-acl-dt:Ipv4-acl-operator-enum
#      |     |     |  +--rw first-destination-port?    ipv4-acl-dt:Ipv4-acl-port-number
#      |     |     |  +--rw second-destination-port?   ipv4-acl-dt:Ipv4-acl-port-number
#      |     |     +--rw icmp
#      |     |     |  +--rw icmp-type-code?   ipv4-acl-dt:Ipv4-acl-icmp-type-code-enum
#      |     |     +--rw tcp
#      |     |     |  +--rw tcp-bits-match-operator?   ipv4-acl-dt:Ipv4-acl-tcp-match-operator-enum
#      |     |     |  +--rw tcp-bits?                  ipv4-acl-dt:Ipv4-acl-tcp-bits-number
#      |     |     |  +--rw tcp-bits-mask?             ipv4-acl-dt:Ipv4-acl-tcp-bits-number
#      |     |     +--rw packet-length
#      |     |     |  +--rw packet-length-operator?   ipv4-acl-dt:Ipv4-acl-operator-enum
#      |     |     |  +--rw packet-length-min?        ipv4-acl-dt:Ipv4-acl-plen-range
#      |     |     |  +--rw packet-length-max?        ipv4-acl-dt:Ipv4-acl-plen-range
#      |     |     +--rw time-to-live
#      |     |     |  +--rw time-to-live-operator?   ipv4-acl-dt:Ipv4-acl-operator-enum
#      |     |     |  +--rw time-to-live-min?        ipv4-acl-dt:Ipv4-acl-ttl-range
#      |     |     |  +--rw time-to-live-max?        ipv4-acl-dt:Ipv4-acl-ttl-range
#      |     |     +--rw fragment-offset
#      |     |     |  +--rw fragment-offset-operator?   ipv4-acl-dt:Ipv4-acl-operator-enum
#      |     |     |  +--rw fragment-offset-1?          ipv4-acl-dt:Ipv4-acl-frag-offset-range
#      |     |     |  +--rw fragment-offset-2?          ipv4-acl-dt:Ipv4-acl-frag-offset-range
#      |     |     +--rw fragment-type?              ipv4-acl-dt:Ipv4-acl-frag-flags
#      |     |     +--rw next-hop
#      |     |     |  +--rw next-hop-type?   Next-hop-type
#      |     |     |  +--rw next-hop-1
#      |     |     |  |  +--rw next-hop?     inet:ipv4-address-no-zone
#      |     |     |  |  +--rw vrf-name?     string
#      |     |     |  |  +--rw track-name?   string
#      |     |     |  +--rw next-hop-2
#      |     |     |  |  +--rw next-hop?     inet:ipv4-address-no-zone
#      |     |     |  |  +--rw vrf-name?     string
#      |     |     |  |  +--rw track-name?   string
#      |     |     |  +--rw next-hop-3
#      |     |     |     +--rw next-hop?     inet:ipv4-address-no-zone
#      |     |     |     +--rw vrf-name?     string
#      |     |     |     +--rw track-name?   string
#      |     |     +--rw counter-name?               string
#      |     |     +--rw igmp-message-type?          ipv4-acl-dt:Ipv4-acl-igmp-number
#      |     |     +--rw dscp
#      |     |     |  +--rw dscp-operator?   ipv4-acl-dt:Ipv4-acl-operator-enum
#      |     |     |  +--rw dscp-min?        ipv4-acl-dt:Ipv4-acl-dscp-number
#      |     |     |  +--rw dscp-max?        ipv4-acl-dt:Ipv4-acl-dscp-number
#      |     |     +--rw precedence?                 ipv4-acl-dt:Ipv4-acl-precedence-number
#      |     |     +--rw log-option?                 ipv4-acl-dt:Ipv4-acl-logging-enum
#      |     |     +--rw capture?                    boolean
#      |     |     +--rw icmp-off?                   empty
#      |     |     +--rw qos-group?                  ipv4-acl-dt:Ipv4-acl-qos-group-number
#      |     |     +--rw set-ttl?                    ipv4-acl-dt:Ipv4-acl-ttl-range
#      |     |     +--rw fragments?                  empty
#      |     |     +--rw remark?                     string
#      |     |     +--rw source-prefix-group?        string
#      |     |     +--rw destination-prefix-group?   string
#      |     |     +--rw source-port-group?          string
#      |     |     +--rw destination-port-group?     string
#      |     |     +--rw sequence-str?               string
#      |     +--rw access-list-name       xr:Cisco-ios-xr-string
#      +--rw prefixes
#      |  +--rw prefix* [prefix-list-name]
#      |     +--rw prefix-list-entries
#      |     |  +--rw prefix-list-entry* [sequence-number]
#      |     |     +--rw sequence-number        dt1:Ipv4-acl-sequence-number-range
#      |     |     +--rw grant?                 dt1:Ipv4-acl-grant-enum
#      |     |     +--rw prefix?                inet:ipv4-address-no-zone
#      |     |     +--rw netmask?               inet:ipv4-address-no-zone
#      |     |     +--rw match-exact-length?    empty
#      |     |     +--rw exact-prefix-length?   dt1:Ipv4-acl-prefix-length-range
#      |     |     +--rw match-max-length?      empty
#      |     |     +--rw max-prefix-length?     dt1:Ipv4-acl-prefix-length-range
#      |     |     +--rw match-min-length?      empty
#      |     |     +--rw min-prefix-length?     dt1:Ipv4-acl-prefix-length-range
#      |     |     +--rw remark?                string
#      |     +--rw prefix-list-name       string
#      +--rw log-update
#         +--rw threshold?   dt1:Ipv4-acl-log-threshold-range
#         +--rw rate?        dt1:Ipv4-acl-log-rate-range

# %% [markdown]
# ¿Qué significa la simbología a la derecha de cada elemento?:
#
# -	```?``` indica que el elemento es opcional
# -	```*``` indica una lista o múltiples instancias (es decir, el elemento puede aparecer cero o más veces).
# -	```!``` representa una elección (solo una de las opciones disponibles puede ser seleccionada).

# %% [markdown]
# ### ⚡️ 3 - Leer & configurar usando este modelo de datos
#
# Vamos ahora a filtrar de las configuraciones actuales (base de datos ```running```) las ACLs existentes

# %%
acl_filter = """
<filter>
  <ipv4-acl-and-prefix-list xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-acl-cfg">
  </ipv4-acl-and-prefix-list>
</filter>
"""
my_acls = xr.get_config(source='running', filter=(acl_filter))
print(my_acls)
# Out:
# <?xml version="1.0"?>
# <rpc-reply message-id="urn:uuid:b4134680-1ac0-4b8d-9004-971a17e79ed3" xmlns:nc="urn:ietf:params:xml:ns:netconf:base:1.0" xmlns="urn:ietf:params:xml:ns:netconf:base:1.0">
#  <data>
#   <ipv4-acl-and-prefix-list xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-acl-cfg">
#    <accesses>
#     <access>
#      <access-list-name>acl_1</access-list-name>
#      <access-list-entries>
#       <access-list-entry>
#        <sequence-number>10</sequence-number>
#        <remark>Block-Denial-of-Service</remark>
#        <sequence-str>10</sequence-str>
#       </access-list-entry>
#       <access-list-entry>
#        <sequence-number>100</sequence-number>
#        <grant>deny</grant>
#        <source-network>
#         <source-address>192.0.2.10</source-address>
#        </source-network>
#        <sequence-str>100</sequence-str>
#       </access-list-entry>
#       <access-list-entry>
#        <sequence-number>200</sequence-number>
#        <grant>deny</grant>
#        <source-network>
#         <source-address>192.0.2.11</source-address>
#        </source-network>
#        <sequence-str>200</sequence-str>
#       </access-list-entry>
#       <access-list-entry>
#        <sequence-number>300</sequence-number>
#        <grant>deny</grant>
#        <source-network>
#         <source-address>192.0.2.12</source-address>
#        </source-network>
#        <sequence-str>300</sequence-str>
#       </access-list-entry>
#       <access-list-entry>
#        <sequence-number>400</sequence-number>
#        <grant>deny</grant>
#        <source-network>
#         <source-address>192.0.2.13</source-address>
#        </source-network>
#        <sequence-str>400</sequence-str>
#       </access-list-entry>
#       <access-list-entry>
#        <sequence-number>500</sequence-number>
#        <grant>deny</grant>
#        <source-network>
#         <source-address>192.0.2.14</source-address>
#        </source-network>
#        <sequence-str>500</sequence-str>
#       </access-list-entry>
#       <access-list-entry>
#        <sequence-number>600</sequence-number>
#        <grant>deny</grant>
#        <source-network>
#         <source-address>192.0.2.15</source-address>
#        </source-network>
#        <sequence-str>600</sequence-str>
#       </access-list-entry>
#       <access-list-entry>
#        <sequence-number>700</sequence-number>
#        <grant>deny</grant>
#        <source-network>
#         <source-address>192.0.2.16</source-address>
#        </source-network>
#        <sequence-str>700</sequence-str>
#       </access-list-entry>
#       <access-list-entry>
#        <sequence-number>10000</sequence-number>
#        <grant>permit</grant>
#        <sequence-str>10000</sequence-str>
#       </access-list-entry>
#      </access-list-entries>
#     </access>
#     <access>
#      <access-list-name>acl_manual</access-list-name>
#      <access-list-entries>
#       <access-list-entry>
#        <sequence-number>100</sequence-number>
#        <grant>deny</grant>
#        <source-network>
#         <source-address>192.0.2.10</source-address>
#        </source-network>
#        <sequence-str>100</sequence-str>
#       </access-list-entry>
#      </access-list-entries>
#     </access>
#    </accesses>
#   </ipv4-acl-and-prefix-list>
#  </data>
# </rpc-reply>

# %% [markdown]
# Podemos ahora ocupar este payload de ejemplo para crear nuestra propia configuración, añadiendo parámetros un poco más complejos.
#
# Vamos entonces a hacer commit de esta configuración pero en la base de datos ```candidate``` del router. De esta manera podemos validar la integridad de nuestro XML. Posteriormente podríamos hacer commit hacia la base de datos ```running```.

# %%
new_acl = '''
<config>
  <ipv4-acl-and-prefix-list xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-acl-cfg">
    <accesses>
      <access>
        <access-list-name>test_witcom_ACL</access-list-name>
        <access-list-entries>

          <access-list-entry>
            <sequence-number>10</sequence-number>
            <remark>ACL de prueba WITCOM</remark>
          </access-list-entry>
          
          <!-- permit tcp 192.168.1.0 host 10.0.0.1 eq 80 -->
          <access-list-entry>
            <sequence-number>20</sequence-number>
            <grant>permit</grant>
            <protocol>6</protocol>
            <source-network>
              <source-address>192.168.1.0</source-address>
            </source-network>
            <destination-network>
              <destination-address>10.0.0.1</destination-address>
            </destination-network>
            <destination-port>
              <destination-operator>equal</destination-operator>
              <first-destination-port>80</first-destination-port>
            </destination-port>
          </access-list-entry>
          
          <!-- permit tcp any any eq 22 -->
          <access-list-entry>
            <sequence-number>30</sequence-number>
            <grant>permit</grant>
            <protocol>6</protocol>
            <destination-port>
              <destination-operator>equal</destination-operator>
              <first-destination-port>22</first-destination-port>
            </destination-port>
          </access-list-entry>
          
          <!-- deny udp any any eq 53 -->
          <access-list-entry>
            <sequence-number>40</sequence-number>
            <grant>deny</grant>
            <protocol>17</protocol>
            <destination-port>
              <destination-operator>equal</destination-operator>
              <first-destination-port>53</first-destination-port>
            </destination-port>
          </access-list-entry>
          
          <!-- deny ip any any -->
          <access-list-entry>
            <sequence-number>50</sequence-number>
            <grant>deny</grant>
            <protocol>0</protocol>
          </access-list-entry>
          
        </access-list-entries>
      </access>
    </accesses>
  </ipv4-acl-and-prefix-list>
</config>
'''

test = xr.edit_config(new_acl, target='candidate', format='xml')
print(test)
# Out:
# <?xml version="1.0"?>
# <rpc-reply message-id="urn:uuid:d45623ff-cc86-4379-9ca8-5a8fb710bafb" xmlns:nc="urn:ietf:params:xml:ns:netconf:base:1.0" xmlns="urn:ietf:params:xml:ns:netconf:base:1.0">
#  <ok/>
# </rpc-reply>

# %% [markdown]
# ***
# 🇲🇽🌊🤖 WITCOM 2024
